# %%
# Install necessary libraries
# !pip install rfdetr supervision albumentations opencv-python torch torchvision --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 5.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 89.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 49.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 50.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.9/354.9 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 87.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.9/774.9 kB 36.0 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.

# %%
import pandas as pd
import json
import os
import shutil
import numpy as np
from sklearn.model_selection import train_test_split
from PIL import Image
from rfdetr import RFDETRBase

# =====================
# Dataset Configuration
# =====================
dataset_dir = "/kaggle/input/mobilephoneusagedatasetiitr"
positive_dir = os.path.join(dataset_dir, "positive")
negative_dir = os.path.join(dataset_dir, "negative")
labels_csv = os.path.join(dataset_dir, "labels.csv")

# ====================
# COCO Conversion Setup
# ====================
output_dir = "/kaggle/working/coco_dataset"
os.makedirs(output_dir, exist_ok=True)

# ===================
# Data Preparation
# ===================
# Read and process labels
labels_df = pd.read_csv(labels_csv)

# Simplified serialization approach
def convert_value(val):
    return int(val) if isinstance(val, (np.integer, int)) else float(val) if isinstance(val, (np.floating, float)) else val

# Verify required columns exist
required_columns = ['filename', 'width', 'height', 'xmin', 'ymin', 'xmax', 'ymax', 'class']
missing_cols = [col for col in required_columns if col not in labels_df.columns]
if missing_cols:
    raise ValueError(f"Missing required columns in CSV: {missing_cols}")

print("Detected columns in CSV:")
print(labels_df.columns.tolist())

# Create image registry
image_registry = {
    "positive": {},
    "negative": []
}

# Process positive images
for _, row in labels_df.iterrows():
    filename = row['filename']
    if filename not in image_registry["positive"]:
        image_registry["positive"][filename] = []
    
    # Convert to COCO bbox format [x, y, width, height]
    x = convert_value(row['xmin'])
    y = convert_value(row['ymin'])
    w = convert_value(row['xmax'] - row['xmin'])  # Convert from xmax to width
    h = convert_value(row['ymax'] - row['ymin'])  # Convert from ymax to height
    
    image_registry["positive"][filename].append([x, y, w, h])

# Add negative images
negative_images = [f for f in os.listdir(negative_dir) if f.endswith((".jpg", ".png", ".jpeg"))]
image_registry["negative"] = negative_images

# ===================
# Dataset Splitting
# ===================
# Create balanced splits
positive_samples = list(image_registry["positive"].keys())
negative_samples = image_registry["negative"]

# Split positive images
train_pos, test_pos = train_test_split(positive_samples, test_size=0.2, random_state=42)
train_pos, val_pos = train_test_split(train_pos, test_size=0.125, random_state=42)  # 70-10-20 split

# Split negative images
train_neg, test_neg = train_test_split(negative_samples, test_size=0.2, random_state=42)
train_neg, val_neg = train_test_split(train_neg, test_size=0.125, random_state=42)

# ===================
# COCO JSON Creation
# ===================
def create_coco_split(split_name, pos_files, neg_files):
    split_dir = os.path.join(output_dir, split_name)
    os.makedirs(split_dir, exist_ok=True)
    
    coco_data = {
        "info": {"description": "Mobile Phone Detection Dataset"},
        "licenses": [{"name": "MIT"}],
        "categories": [{
            "id": 0, 
            "name": "mobile phone",
            "supercategory": "object"  # Added required supercategory field
        }],
        "images": [],
        "annotations": []
    }
    
    annotation_id = 1
    
    # Process positive images
    for idx, filename in enumerate(pos_files):
        # Copy image
        src_path = os.path.join(positive_dir, filename)
        dest_path = os.path.join(split_dir, filename)
        shutil.copy(src_path, dest_path)
        
        # Get image dimensions from CSV
        img_row = labels_df[labels_df['filename'] == filename].iloc[0]
        width = convert_value(img_row['width'])
        height = convert_value(img_row['height'])
        
        # Create image entry
        image_id = idx + 1
        coco_data["images"].append({
            "id": image_id,
            "file_name": filename,
            "width": width,
            "height": height,
            "license": 1,
            "date_captured": "2024-01-01"
        })
        
        # Create annotations
        for bbox in image_registry["positive"][filename]:
            coco_data["annotations"].append({
                "id": annotation_id,
                "image_id": image_id,
                "category_id": 0,
                "bbox": bbox,
                "area": convert_value(bbox[2] * bbox[3]),
                "iscrowd": 0
            })
            annotation_id += 1
    
    # Process negative images
    for idx, filename in enumerate(neg_files, start=len(pos_files)):
        src_path = os.path.join(negative_dir, filename)
        dest_path = os.path.join(split_dir, filename)
        shutil.copy(src_path, dest_path)
        
        # Get dimensions from image
        with Image.open(src_path) as img:
            width, height = img.size
        
        coco_data["images"].append({
            "id": idx + 1,
            "file_name": filename,
            "width": convert_value(width),
            "height": convert_value(height),
            "license": 1,
            "date_captured": "2024-01-01"
        })
    
    # Save COCO JSON with default encoder
    with open(os.path.join(split_dir, "_annotations.coco.json"), "w") as f:
        json.dump(coco_data, f, indent=2)

# Create splits
create_coco_split("train", train_pos, train_neg)
create_coco_split("valid", val_pos, val_neg)
create_coco_split("test", test_pos, test_neg)

# ===================
# Model Training
# ===================
# Install required packages
# !pip install rfdetr[metrics] --quiet

# Training configuration
model = RFDETRBase(resolution=448)  # Higher resolution for better accuracy

model.train(
    dataset_dir=output_dir,
    epochs=100,
    batch_size=8,
    grad_accum_steps=2,
    lr=1e-4,
    output_dir="/kaggle/working/output",
    early_stopping=True,
    early_stopping_patience=10,
    tensorboard=True,
    wandb=False
)

print("Training completed successfully!")
# Out:
# Detected columns in CSV:
# ['filename', 'width', 'height', 'xmin', 'ymin', 'xmax', 'ymax', 'class']
# rf-detr-base.pth: 100%|██████████| 355M/355M [00:04<00:00, 88.9MiB/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/88.2M [00:00<?, ?B/s]
# Loading pretrain weights
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir /kaggle/working/output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=1, grad_accum_steps=2, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=8, weight_decay=0.0001, epochs=100, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-base.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[2, 5, 8, 11], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='/kaggle/working/coco_dataset', square_resize_div_64=True, output_dir='/kaggle/working/output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=448, use_cls_token=False, multi_scale=True, expanded_scales=True, warmup_epochs=0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=True, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, tensorboard=True, wandb=False, project=None, run=None, class_names=['mobile phone'], distributed=False)
# number of params: 31850710
# [280, 336, 392, 448, 504, 560, 616, 672]
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [280, 336, 392, 448, 504, 560, 616, 672]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  2
# Total batch size:  16
# LENGTH OF DATA LOADER: 38
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
# Epoch: [0]  [ 0/38]  eta: 0:07:00  lr: 0.000100  class_error: 0.00  loss: 14.4324 (14.4324)  loss_ce: 0.7487 (0.7487)  loss_bbox: 1.3304 (1.3304)  loss_giou: 1.3228 (1.3228)  loss_ce_0: 0.6511 (0.6511)  loss_bbox_0: 1.6978 (1.6978)  loss_giou_0: 1.4370 (1.4370)  loss_ce_1: 0.7419 (0.7419)  loss_bbox_1: 1.3253 (1.3253)  loss_giou_1: 1.3647 (1.3647)  loss_ce_enc: 0.7100 (0.7100)  loss_bbox_enc: 1.6965 (1.6965)  loss_giou_enc: 1.4065 (1.4065)  loss_ce_unscaled: 0.7487 (0.7487)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.2661 (0.2661)  loss_giou_unscaled: 0.6614 (0.6614)  cardinality_error_unscaled: 0.5000 (0.5000)  loss_ce_0_unscaled: 0.6511 (0.6511)  loss_bbox_0_unscaled: 0.3396 (0.3396)  loss_giou_0_unscaled: 0.7185 (0.7185)  cardinality_error_0_unscaled: 0.5000 (0.5000)  loss_ce_1_unscaled: 0.7419 (0.7419)  loss_bbox_1_unscaled: 0.2651 (0.2651)  loss_giou_1_unscaled: 0.6823 (0.6823)  cardinality_error_1_unscaled: 0.5000 (0.5000)  loss_ce_enc_unscaled: 0.7100 (0.7100)  loss_bbox_enc_unscaled: 0.3393 (0.3393)  loss_giou_enc_unscaled: 0.7032 (0.7032)  cardinality_error_enc_unscaled: 0.5000 (0.5000)  time: 11.0783  data: 1.8755  max mem: 12692
# Epoch: [0]  [10/38]  eta: 0:02:34  lr: 0.000100  class_error: 0.00  loss: 13.2638 (13.2393)  loss_ce: 0.7546 (0.7876)  loss_bbox: 1.0979 (1.1115)  loss_giou: 1.3228 (1.2842)  loss_ce_0: 0.7048 (0.7424)  loss_bbox_0: 1.2574 (1.2810)  loss_giou_0: 1.4146 (1.3459)  loss_ce_1: 0.7419 (0.7678)  loss_bbox_1: 1.2336 (1.1752)  loss_giou_1: 1.3647 (1.3151)  loss_ce_enc: 0.7145 (0.7370)  loss_bbox_enc: 1.3216 (1.3061)  loss_giou_enc: 1.4315 (1.3855)  loss_ce_unscaled: 0.7546 (0.7876)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.2196 (0.2223)  loss_giou_unscaled: 0.6614 (0.6421)  cardinality_error_unscaled: 0.5000 (0.7159)  loss_ce_0_unscaled: 0.7048 (0.7424)  loss_bbox_0_unscaled: 0.2515 (0.2562)  loss_giou_0_unscaled: 0.7073 (0.6730)  cardinality_error_0_unscaled: 0.5000 (0.7159)  loss_ce_1_unscaled: 0.7419 (0.7678)  loss_bbox_1_unscaled: 0.2467 (0.2350)  loss_giou_1_unscaled: 0.6823 (0.6576)  cardinality_error_1_unscaled: 0.5000 (0.7159)  loss_ce_enc_unscaled: 0.7145 (0.7370)  loss_bbox_enc_unscaled: 0.2643 (0.2612)  loss_giou_enc_unscaled: 0.7157 (0.6927)  cardinality_error_enc_unscaled: 0.5000 (0.7159)  time: 5.5288  data: 0.2055  max mem: 12922
# Epoch: [0]  [20/38]  eta: 0:01:39  lr: 0.000100  class_error: 0.00  loss: 11.5463 (12.1115)  loss_ce: 0.8346 (0.8520)  loss_bbox: 0.8421 (0.9109)  loss_giou: 1.1677 (1.1472)  loss_ce_0: 0.8097 (0.8205)  loss_bbox_0: 0.8984 (1.0186)  loss_giou_0: 1.2110 (1.2028)  loss_ce_1: 0.7934 (0.8316)  loss_bbox_1: 0.8713 (0.9631)  loss_giou_1: 1.1791 (1.1809)  loss_ce_enc: 0.7488 (0.7868)  loss_bbox_enc: 1.0648 (1.1071)  loss_giou_enc: 1.2760 (1.2900)  loss_ce_unscaled: 0.8346 (0.8520)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.1684 (0.1822)  loss_giou_unscaled: 0.5838 (0.5736)  cardinality_error_unscaled: 0.5000 (0.6786)  loss_ce_0_unscaled: 0.8097 (0.8205)  loss_bbox_0_unscaled: 0.1797 (0.2037)  loss_giou_0_unscaled: 0.6055 (0.6014)  cardinality_error_0_unscaled: 0.5000 (0.6786)  loss_ce_1_unscaled: 0.7934 (0.8316)  loss_bbox_1_unscaled: 0.1743 (0.1926)  loss_giou_1_unscaled: 0.5896 (0.5904)  cardinality_error_1_unscaled: 0.5000 (0.6786)  loss_ce_enc_unscaled: 0.7488 (0.7868)  loss_bbox_enc_unscaled: 0.2130 (0.2214)  loss_giou_enc_unscaled: 0.6380 (0.6450)  cardinality_error_enc_unscaled: 0.5000 (0.6786)  time: 5.2397  data: 0.0373  max mem: 12923
# Epoch: [0]  [30/38]  eta: 0:00:44  lr: 0.000100  class_error: 0.00  loss: 10.0256 (11.3621)  loss_ce: 1.0155 (0.9248)  loss_bbox: 0.5537 (0.7905)  loss_giou: 0.8224 (1.0336)  loss_ce_0: 1.0162 (0.8886)  loss_bbox_0: 0.6379 (0.8747)  loss_giou_0: 0.8430 (1.0784)  loss_ce_1: 0.9882 (0.8906)  loss_bbox_1: 0.6100 (0.8267)  loss_giou_1: 0.8500 (1.0574)  loss_ce_enc: 0.9136 (0.8430)  loss_bbox_enc: 0.6794 (0.9681)  loss_giou_enc: 1.0327 (1.1856)  loss_ce_unscaled: 1.0155 (0.9248)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.1107 (0.1581)  loss_giou_unscaled: 0.4112 (0.5168)  cardinality_error_unscaled: 0.5000 (0.6492)  loss_ce_0_unscaled: 1.0162 (0.8886)  loss_bbox_0_unscaled: 0.1276 (0.1749)  loss_giou_0_unscaled: 0.4215 (0.5392)  cardinality_error_0_unscaled: 0.5000 (0.6492)  loss_ce_1_unscaled: 0.9882 (0.8906)  loss_bbox_1_unscaled: 0.1220 (0.1653)  loss_giou_1_unscaled: 0.4250 (0.5287)  cardinality_error_1_unscaled: 0.5000 (0.6492)  loss_ce_enc_unscaled: 0.9136 (0.8430)  loss_bbox_enc_unscaled: 0.1359 (0.1936)  loss_giou_enc_unscaled: 0.5163 (0.5928)  cardinality_error_enc_unscaled: 0.5000 (0.6492)  time: 5.6280  data: 0.0354  max mem: 12923
# Epoch: [0]  [37/38]  eta: 0:00:05  lr: 0.000100  class_error: 0.00  loss: 9.5198 (10.9760)  loss_ce: 1.0155 (0.9443)  loss_bbox: 0.4749 (0.7303)  loss_giou: 0.7642 (0.9717)  loss_ce_0: 1.0295 (0.9239)  loss_bbox_0: 0.5386 (0.8087)  loss_giou_0: 0.7905 (1.0115)  loss_ce_1: 1.0201 (0.9262)  loss_bbox_1: 0.4981 (0.7670)  loss_giou_1: 0.7907 (0.9964)  loss_ce_enc: 0.9358 (0.8765)  loss_bbox_enc: 0.6552 (0.8965)  loss_giou_enc: 0.9533 (1.1230)  loss_ce_unscaled: 1.0155 (0.9443)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0950 (0.1461)  loss_giou_unscaled: 0.3821 (0.4859)  cardinality_error_unscaled: 0.5000 (0.6480)  loss_ce_0_unscaled: 1.0295 (0.9239)  loss_bbox_0_unscaled: 0.1077 (0.1617)  loss_giou_0_unscaled: 0.3953 (0.5057)  cardinality_error_0_unscaled: 0.5000 (0.6480)  loss_ce_1_unscaled: 1.0201 (0.9262)  loss_bbox_1_unscaled: 0.0996 (0.1534)  loss_giou_1_unscaled: 0.3954 (0.4982)  cardinality_error_1_unscaled: 0.5000 (0.6480)  loss_ce_enc_unscaled: 0.9358 (0.8765)  loss_bbox_enc_unscaled: 0.1310 (0.1793)  loss_giou_enc_unscaled: 0.4767 (0.5615)  cardinality_error_enc_unscaled: 0.5000 (0.6480)  time: 5.7422  data: 0.0361  max mem: 12923
# Epoch: [0] Total time: 0:03:32 (5.6045 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 9.5198 (10.9760)  loss_ce: 1.0155 (0.9443)  loss_bbox: 0.4749 (0.7303)  loss_giou: 0.7642 (0.9717)  loss_ce_0: 1.0295 (0.9239)  loss_bbox_0: 0.5386 (0.8087)  loss_giou_0: 0.7905 (1.0115)  loss_ce_1: 1.0201 (0.9262)  loss_bbox_1: 0.4981 (0.7670)  loss_giou_1: 0.7907 (0.9964)  loss_ce_enc: 0.9358 (0.8765)  loss_bbox_enc: 0.6552 (0.8965)  loss_giou_enc: 0.9533 (1.1230)  loss_ce_unscaled: 1.0155 (0.9443)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0950 (0.1461)  loss_giou_unscaled: 0.3821 (0.4859)  cardinality_error_unscaled: 0.5000 (0.6480)  loss_ce_0_unscaled: 1.0295 (0.9239)  loss_bbox_0_unscaled: 0.1077 (0.1617)  loss_giou_0_unscaled: 0.3953 (0.5057)  cardinality_error_0_unscaled: 0.5000 (0.6480)  loss_ce_1_unscaled: 1.0201 (0.9262)  loss_bbox_1_unscaled: 0.0996 (0.1534)  loss_giou_1_unscaled: 0.3954 (0.4982)  cardinality_error_1_unscaled: 0.5000 (0.6480)  loss_ce_enc_unscaled: 0.9358 (0.8765)  loss_bbox_enc_unscaled: 0.1310 (0.1793)  loss_giou_enc_unscaled: 0.4767 (0.5615)  cardinality_error_enc_unscaled: 0.5000 (0.6480)
# Test:  [ 0/12]  eta: 0:00:18  class_error: 0.00  loss: 8.2584 (8.2584)  loss_ce: 1.0312 (1.0312)  loss_bbox: 0.3079 (0.3079)  loss_giou: 0.5473 (0.5473)  loss_ce_0: 1.1094 (1.1094)  loss_bbox_0: 0.4349 (0.4349)  loss_giou_0: 0.6022 (0.6022)  loss_ce_1: 1.0469 (1.0469)  loss_bbox_1: 0.3402 (0.3402)  loss_giou_1: 0.7126 (0.7126)  loss_ce_enc: 1.1250 (1.1250)  loss_bbox_enc: 0.3343 (0.3343)  loss_giou_enc: 0.6665 (0.6665)  loss_ce_unscaled: 1.0312 (1.0312)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0616 (0.0616)  loss_giou_unscaled: 0.2736 (0.2736)  cardinality_error_unscaled: 1.0000 (1.0000)  loss_ce_0_unscaled: 1.1094 (1.1094)  loss_bbox_0_unscaled: 0.0870 (0.0870)  loss_giou_0_unscaled: 0.3011 (0.3011)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 1.0469 (1.0469)  loss_bbox_1_unscaled: 0.0680 (0.0680)  loss_giou_1_unscaled: 0.3563 (0.3563)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_enc_unscaled: 1.1250 (1.1250)  loss_bbox_enc_unscaled: 0.0669 (0.0669)  loss_giou_enc_unscaled: 0.3332 (0.3332)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 1.5465  data: 0.9438  max mem: 12923
# Test:  [10/12]  eta: 0:00:01  class_error: 100.00  loss: 7.9956 (5.8900)  loss_ce: 0.9102 (0.7390)  loss_bbox: 0.3079 (0.2474)  loss_giou: 0.5473 (0.4364)  loss_ce_0: 1.0000 (0.7521)  loss_bbox_0: 0.3189 (0.2464)  loss_giou_0: 0.6022 (0.4255)  loss_ce_1: 1.0312 (0.9407)  loss_bbox_1: 0.3402 (0.2487)  loss_giou_1: 0.6399 (0.4530)  loss_ce_enc: 1.0312 (0.7502)  loss_bbox_enc: 0.2886 (0.2262)  loss_giou_enc: 0.5467 (0.4245)  loss_ce_unscaled: 0.9102 (0.7390)  class_error_unscaled: 0.0000 (36.3636)  loss_bbox_unscaled: 0.0616 (0.0495)  loss_giou_unscaled: 0.2736 (0.2182)  cardinality_error_unscaled: 1.0000 (0.7159)  loss_ce_0_unscaled: 1.0000 (0.7521)  loss_bbox_0_unscaled: 0.0638 (0.0493)  loss_giou_0_unscaled: 0.3011 (0.2127)  cardinality_error_0_unscaled: 1.0000 (0.7159)  loss_ce_1_unscaled: 1.0312 (0.9407)  loss_bbox_1_unscaled: 0.0680 (0.0497)  loss_giou_1_unscaled: 0.3200 (0.2265)  cardinality_error_1_unscaled: 1.0000 (0.7159)  loss_ce_enc_unscaled: 1.0312 (0.7502)  loss_bbox_enc_unscaled: 0.0577 (0.0452)  loss_giou_enc_unscaled: 0.2734 (0.2122)  cardinality_error_enc_unscaled: 1.0000 (0.7159)  time: 0.5868  data: 0.1994  max mem: 12923
# Test:  [11/12]  eta: 0:00:00  class_error: 100.00  loss: 7.0581 (5.4166)  loss_ce: 0.8594 (0.6811)  loss_bbox: 0.2995 (0.2268)  loss_giou: 0.5222 (0.4000)  loss_ce_0: 1.0000 (0.6914)  loss_bbox_0: 0.1888 (0.2258)  loss_giou_0: 0.3732 (0.3900)  loss_ce_1: 0.9688 (0.8729)  loss_bbox_1: 0.1930 (0.2280)  loss_giou_1: 0.4064 (0.4152)  loss_ce_enc: 1.0234 (0.6888)  loss_bbox_enc: 0.1827 (0.2074)  loss_giou_enc: 0.4352 (0.3891)  loss_ce_unscaled: 0.8594 (0.6811)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0599 (0.0454)  loss_giou_unscaled: 0.2611 (0.2000)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 1.0000 (0.6914)  loss_bbox_0_unscaled: 0.0378 (0.0452)  loss_giou_0_unscaled: 0.1866 (0.1950)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 0.9688 (0.8729)  loss_bbox_1_unscaled: 0.0386 (0.0456)  loss_giou_1_unscaled: 0.2032 (0.2076)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 1.0234 (0.6888)  loss_bbox_enc_unscaled: 0.0365 (0.0415)  loss_giou_enc_unscaled: 0.2176 (0.1946)  cardinality_error_enc_unscaled: 1.0000 (0.6562)  time: 0.5434  data: 0.1836  max mem: 12923
# Test: Total time: 0:00:06 (0.5475 s / it)
# Averaged stats: class_error: 100.00  loss: 7.0581 (5.4166)  loss_ce: 0.8594 (0.6811)  loss_bbox: 0.2995 (0.2268)  loss_giou: 0.5222 (0.4000)  loss_ce_0: 1.0000 (0.6914)  loss_bbox_0: 0.1888 (0.2258)  loss_giou_0: 0.3732 (0.3900)  loss_ce_1: 0.9688 (0.8729)  loss_bbox_1: 0.1930 (0.2280)  loss_giou_1: 0.4064 (0.4152)  loss_ce_enc: 1.0234 (0.6888)  loss_bbox_enc: 0.1827 (0.2074)  loss_giou_enc: 0.4352 (0.3891)  loss_ce_unscaled: 0.8594 (0.6811)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0599 (0.0454)  loss_giou_unscaled: 0.2611 (0.2000)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 1.0000 (0.6914)  loss_bbox_0_unscaled: 0.0378 (0.0452)  loss_giou_0_unscaled: 0.1866 (0.1950)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 0.9688 (0.8729)  loss_bbox_1_unscaled: 0.0386 (0.0456)  loss_giou_1_unscaled: 0.2032 (0.2076)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 1.0234 (0.6888)  loss_bbox_enc_unscaled: 0.0365 (0.0415)  loss_giou_enc_unscaled: 0.2176 (0.1946)  cardinality_error_enc_unscaled: 1.0000 (0.6562)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.147
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.399
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.149
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.277
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.418
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.474
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.481
# Test:  [ 0/12]  eta: 0:00:18  class_error: 0.00  loss: 8.3054 (8.3054)  loss_ce: 1.0391 (1.0391)  loss_bbox: 0.3111 (0.3111)  loss_giou: 0.5654 (0.5654)  loss_ce_0: 1.1094 (1.1094)  loss_bbox_0: 0.4454 (0.4454)  loss_giou_0: 0.6077 (0.6077)  loss_ce_1: 1.0625 (1.0625)  loss_bbox_1: 0.3858 (0.3858)  loss_giou_1: 0.6547 (0.6547)  loss_ce_enc: 1.1250 (1.1250)  loss_bbox_enc: 0.3353 (0.3353)  loss_giou_enc: 0.6641 (0.6641)  loss_ce_unscaled: 1.0391 (1.0391)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0622 (0.0622)  loss_giou_unscaled: 0.2827 (0.2827)  cardinality_error_unscaled: 1.0000 (1.0000)  loss_ce_0_unscaled: 1.1094 (1.1094)  loss_bbox_0_unscaled: 0.0891 (0.0891)  loss_giou_0_unscaled: 0.3039 (0.3039)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 1.0625 (1.0625)  loss_bbox_1_unscaled: 0.0772 (0.0772)  loss_giou_1_unscaled: 0.3274 (0.3274)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_enc_unscaled: 1.1250 (1.1250)  loss_bbox_enc_unscaled: 0.0671 (0.0671)  loss_giou_enc_unscaled: 0.3320 (0.3320)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 1.5702  data: 1.0697  max mem: 12923
# Test:  [10/12]  eta: 0:00:01  class_error: 100.00  loss: 8.0481 (5.9202)  loss_ce: 0.9141 (0.7496)  loss_bbox: 0.3111 (0.2508)  loss_giou: 0.5654 (0.4466)  loss_ce_0: 1.0156 (0.7512)  loss_bbox_0: 0.3224 (0.2435)  loss_giou_0: 0.6077 (0.4289)  loss_ce_1: 1.0547 (0.9585)  loss_bbox_1: 0.3761 (0.2528)  loss_giou_1: 0.6104 (0.4339)  loss_ce_enc: 1.0391 (0.7503)  loss_bbox_enc: 0.3012 (0.2288)  loss_giou_enc: 0.5493 (0.4254)  loss_ce_unscaled: 0.9141 (0.7496)  class_error_unscaled: 0.0000 (36.3636)  loss_bbox_unscaled: 0.0622 (0.0502)  loss_giou_unscaled: 0.2827 (0.2233)  cardinality_error_unscaled: 1.0000 (0.7159)  loss_ce_0_unscaled: 1.0156 (0.7512)  loss_bbox_0_unscaled: 0.0645 (0.0487)  loss_giou_0_unscaled: 0.3039 (0.2144)  cardinality_error_0_unscaled: 1.0000 (0.7159)  loss_ce_1_unscaled: 1.0547 (0.9585)  loss_bbox_1_unscaled: 0.0752 (0.0506)  loss_giou_1_unscaled: 0.3052 (0.2170)  cardinality_error_1_unscaled: 1.0000 (0.7159)  loss_ce_enc_unscaled: 1.0391 (0.7503)  loss_bbox_enc_unscaled: 0.0602 (0.0458)  loss_giou_enc_unscaled: 0.2746 (0.2127)  cardinality_error_enc_unscaled: 1.0000 (0.7159)  time: 0.6008  data: 0.2073  max mem: 12923
# Test:  [11/12]  eta: 0:00:00  class_error: 100.00  loss: 7.0593 (5.4443)  loss_ce: 0.8438 (0.6915)  loss_bbox: 0.2985 (0.2299)  loss_giou: 0.5227 (0.4094)  loss_ce_0: 0.9961 (0.6905)  loss_bbox_0: 0.1826 (0.2232)  loss_giou_0: 0.3828 (0.3931)  loss_ce_1: 1.0234 (0.8887)  loss_bbox_1: 0.1870 (0.2317)  loss_giou_1: 0.4014 (0.3978)  loss_ce_enc: 1.0234 (0.6889)  loss_bbox_enc: 0.1835 (0.2097)  loss_giou_enc: 0.4398 (0.3899)  loss_ce_unscaled: 0.8438 (0.6915)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0597 (0.0460)  loss_giou_unscaled: 0.2614 (0.2047)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 0.9961 (0.6905)  loss_bbox_0_unscaled: 0.0365 (0.0446)  loss_giou_0_unscaled: 0.1914 (0.1966)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 1.0234 (0.8887)  loss_bbox_1_unscaled: 0.0374 (0.0463)  loss_giou_1_unscaled: 0.2007 (0.1989)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 1.0234 (0.6889)  loss_bbox_enc_unscaled: 0.0367 (0.0419)  loss_giou_enc_unscaled: 0.2199 (0.1950)  cardinality_error_enc_unscaled: 1.0000 (0.6562)  time: 0.5568  data: 0.1907  max mem: 12923
# Test: Total time: 0:00:06 (0.5609 s / it)
# Averaged stats: class_error: 100.00  loss: 7.0593 (5.4443)  loss_ce: 0.8438 (0.6915)  loss_bbox: 0.2985 (0.2299)  loss_giou: 0.5227 (0.4094)  loss_ce_0: 0.9961 (0.6905)  loss_bbox_0: 0.1826 (0.2232)  loss_giou_0: 0.3828 (0.3931)  loss_ce_1: 1.0234 (0.8887)  loss_bbox_1: 0.1870 (0.2317)  loss_giou_1: 0.4014 (0.3978)  loss_ce_enc: 1.0234 (0.6889)  loss_bbox_enc: 0.1835 (0.2097)  loss_giou_enc: 0.4398 (0.3899)  loss_ce_unscaled: 0.8438 (0.6915)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0597 (0.0460)  loss_giou_unscaled: 0.2614 (0.2047)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 0.9961 (0.6905)  loss_bbox_0_unscaled: 0.0365 (0.0446)  loss_giou_0_unscaled: 0.1914 (0.1966)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 1.0234 (0.8887)  loss_bbox_1_unscaled: 0.0374 (0.0463)  loss_giou_1_unscaled: 0.2007 (0.1989)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 1.0234 (0.6889)  loss_bbox_enc_unscaled: 0.0367 (0.0419)  loss_giou_enc_unscaled: 0.2199 (0.1950)  cardinality_error_enc_unscaled: 1.0000 (0.6562)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.133
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.277
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.406
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.461
# Early stopping: Current mAP (max(regular, EMA)): 0.1473, Best: 0.0000, Diff: 0.1473, Min delta: 0.001
# Grad accum steps:  2
# Total batch size:  16
# LENGTH OF DATA LOADER: 38
# Epoch: [1]  [ 0/38]  eta: 0:05:11  lr: 0.000100  class_error: 0.00  loss: 8.6363 (8.6363)  loss_ce: 0.8886 (0.8886)  loss_bbox: 0.4433 (0.4433)  loss_giou: 0.8022 (0.8022)  loss_ce_0: 1.0664 (1.0664)  loss_bbox_0: 0.3728 (0.3728)  loss_giou_0: 0.6835 (0.6835)  loss_ce_1: 0.9774 (0.9774)  loss_bbox_1: 0.4165 (0.4165)  loss_giou_1: 0.7429 (0.7429)  loss_ce_enc: 1.0607 (1.0607)  loss_bbox_enc: 0.4285 (0.4285)  loss_giou_enc: 0.7536 (0.7536)  loss_ce_unscaled: 0.8886 (0.8886)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0887 (0.0887)  loss_giou_unscaled: 0.4011 (0.4011)  cardinality_error_unscaled: 1.1250 (1.1250)  loss_ce_0_unscaled: 1.0664 (1.0664)  loss_bbox_0_unscaled: 0.0746 (0.0746)  loss_giou_0_unscaled: 0.3417 (0.3417)  cardinality_error_0_unscaled: 1.1250 (1.1250)  loss_ce_1_unscaled: 0.9774 (0.9774)  loss_bbox_1_unscaled: 0.0833 (0.0833)  loss_giou_1_unscaled: 0.3715 (0.3715)  cardinality_error_1_unscaled: 1.1250 (1.1250)  loss_ce_enc_unscaled: 1.0607 (1.0607)  loss_bbox_enc_unscaled: 0.0857 (0.0857)  loss_giou_enc_unscaled: 0.3768 (0.3768)  cardinality_error_enc_unscaled: 1.1250 (1.1250)  time: 8.2055  data: 2.5179  max mem: 12923
# Epoch: [1]  [10/38]  eta: 0:02:48  lr: 0.000100  class_error: 0.00  loss: 9.0654 (9.1256)  loss_ce: 0.9195 (0.9090)  loss_bbox: 0.4693 (0.4942)  loss_giou: 0.7811 (0.7488)  loss_ce_0: 1.0571 (1.0599)  loss_bbox_0: 0.4816 (0.4778)  loss_giou_0: 0.7076 (0.7268)  loss_ce_1: 0.9840 (0.9917)  loss_bbox_1: 0.4930 (0.4884)  loss_giou_1: 0.7435 (0.7566)  loss_ce_enc: 1.0184 (1.0135)  loss_bbox_enc: 0.6235 (0.5820)  loss_giou_enc: 0.8794 (0.8769)  loss_ce_unscaled: 0.9195 (0.9090)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0939 (0.0988)  loss_giou_unscaled: 0.3905 (0.3744)  cardinality_error_unscaled: 0.7500 (0.7386)  loss_ce_0_unscaled: 1.0571 (1.0599)  loss_bbox_0_unscaled: 0.0963 (0.0956)  loss_giou_0_unscaled: 0.3538 (0.3634)  cardinality_error_0_unscaled: 0.7500 (0.7386)  loss_ce_1_unscaled: 0.9840 (0.9917)  loss_bbox_1_unscaled: 0.0986 (0.0977)  loss_giou_1_unscaled: 0.3717 (0.3783)  cardinality_error_1_unscaled: 0.7500 (0.7386)  loss_ce_enc_unscaled: 1.0184 (1.0135)  loss_bbox_enc_unscaled: 0.1247 (0.1164)  loss_giou_enc_unscaled: 0.4397 (0.4384)  cardinality_error_enc_unscaled: 0.7500 (0.7386)  time: 6.0262  data: 0.2666  max mem: 12923
# Epoch: [1]  [20/38]  eta: 0:01:44  lr: 0.000100  class_error: 0.00  loss: 8.8282 (8.8277)  loss_ce: 0.9087 (0.8978)  loss_bbox: 0.4415 (0.4558)  loss_giou: 0.6878 (0.7212)  loss_ce_0: 1.0741 (1.0980)  loss_bbox_0: 0.3682 (0.4228)  loss_giou_0: 0.6826 (0.6848)  loss_ce_1: 0.9490 (0.9747)  loss_bbox_1: 0.4353 (0.4493)  loss_giou_1: 0.7105 (0.7255)  loss_ce_enc: 1.0619 (1.0485)  loss_bbox_enc: 0.5413 (0.5344)  loss_giou_enc: 0.7627 (0.8149)  loss_ce_unscaled: 0.9087 (0.8978)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0883 (0.0912)  loss_giou_unscaled: 0.3439 (0.3606)  cardinality_error_unscaled: 0.6250 (0.6964)  loss_ce_0_unscaled: 1.0741 (1.0980)  loss_bbox_0_unscaled: 0.0736 (0.0846)  loss_giou_0_unscaled: 0.3413 (0.3424)  cardinality_error_0_unscaled: 0.6250 (0.6964)  loss_ce_1_unscaled: 0.9490 (0.9747)  loss_bbox_1_unscaled: 0.0871 (0.0899)  loss_giou_1_unscaled: 0.3553 (0.3627)  cardinality_error_1_unscaled: 0.6250 (0.6964)  loss_ce_enc_unscaled: 1.0619 (1.0485)  loss_bbox_enc_unscaled: 0.1083 (0.1069)  loss_giou_enc_unscaled: 0.3813 (0.4074)  cardinality_error_enc_unscaled: 0.6250 (0.6964)  time: 5.6633  data: 0.0397  max mem: 12923
# Epoch: [1]  [30/38]  eta: 0:00:45  lr: 0.000100  class_error: 0.00  loss: 8.4217 (8.7771)  loss_ce: 0.8502 (0.8761)  loss_bbox: 0.4338 (0.4605)  loss_giou: 0.6878 (0.7175)  loss_ce_0: 1.0914 (1.1011)  loss_bbox_0: 0.3549 (0.4246)  loss_giou_0: 0.6450 (0.6754)  loss_ce_1: 0.9222 (0.9457)  loss_bbox_1: 0.4241 (0.4594)  loss_giou_1: 0.6972 (0.7225)  loss_ce_enc: 1.0782 (1.0575)  loss_bbox_enc: 0.4713 (0.5374)  loss_giou_enc: 0.7464 (0.7993)  loss_ce_unscaled: 0.8502 (0.8761)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0868 (0.0921)  loss_giou_unscaled: 0.3439 (0.3587)  cardinality_error_unscaled: 0.6250 (0.6935)  loss_ce_0_unscaled: 1.0914 (1.1011)  loss_bbox_0_unscaled: 0.0710 (0.0849)  loss_giou_0_unscaled: 0.3225 (0.3377)  cardinality_error_0_unscaled: 0.6250 (0.6935)  loss_ce_1_unscaled: 0.9222 (0.9457)  loss_bbox_1_unscaled: 0.0848 (0.0919)  loss_giou_1_unscaled: 0.3486 (0.3612)  cardinality_error_1_unscaled: 0.6250 (0.6935)  loss_ce_enc_unscaled: 1.0782 (1.0575)  loss_bbox_enc_unscaled: 0.0943 (0.1075)  loss_giou_enc_unscaled: 0.3732 (0.3996)  cardinality_error_enc_unscaled: 0.6250 (0.6935)  time: 5.5686  data: 0.0391  max mem: 12923
# Epoch: [1]  [37/38]  eta: 0:00:05  lr: 0.000100  class_error: 0.00  loss: 8.9544 (8.7105)  loss_ce: 0.8572 (0.8674)  loss_bbox: 0.4560 (0.4673)  loss_giou: 0.7171 (0.6960)  loss_ce_0: 1.0931 (1.1032)  loss_bbox_0: 0.4459 (0.4341)  loss_giou_0: 0.6450 (0.6546)  loss_ce_1: 0.9181 (0.9416)  loss_bbox_1: 0.4892 (0.4615)  loss_giou_1: 0.6968 (0.6952)  loss_ce_enc: 1.0764 (1.0653)  loss_bbox_enc: 0.5553 (0.5441)  loss_giou_enc: 0.7588 (0.7801)  loss_ce_unscaled: 0.8572 (0.8674)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0912 (0.0935)  loss_giou_unscaled: 0.3586 (0.3480)  cardinality_error_unscaled: 0.6250 (0.6875)  loss_ce_0_unscaled: 1.0931 (1.1032)  loss_bbox_0_unscaled: 0.0892 (0.0868)  loss_giou_0_unscaled: 0.3225 (0.3273)  cardinality_error_0_unscaled: 0.6250 (0.6875)  loss_ce_1_unscaled: 0.9181 (0.9416)  loss_bbox_1_unscaled: 0.0978 (0.0923)  loss_giou_1_unscaled: 0.3484 (0.3476)  cardinality_error_1_unscaled: 0.6250 (0.6875)  loss_ce_enc_unscaled: 1.0764 (1.0653)  loss_bbox_enc_unscaled: 0.1111 (0.1088)  loss_giou_enc_unscaled: 0.3794 (0.3901)  cardinality_error_enc_unscaled: 0.6250 (0.6875)  time: 5.6119  data: 0.0381  max mem: 12923
# Epoch: [1] Total time: 0:03:37 (5.7355 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 8.9544 (8.7105)  loss_ce: 0.8572 (0.8674)  loss_bbox: 0.4560 (0.4673)  loss_giou: 0.7171 (0.6960)  loss_ce_0: 1.0931 (1.1032)  loss_bbox_0: 0.4459 (0.4341)  loss_giou_0: 0.6450 (0.6546)  loss_ce_1: 0.9181 (0.9416)  loss_bbox_1: 0.4892 (0.4615)  loss_giou_1: 0.6968 (0.6952)  loss_ce_enc: 1.0764 (1.0653)  loss_bbox_enc: 0.5553 (0.5441)  loss_giou_enc: 0.7588 (0.7801)  loss_ce_unscaled: 0.8572 (0.8674)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0912 (0.0935)  loss_giou_unscaled: 0.3586 (0.3480)  cardinality_error_unscaled: 0.6250 (0.6875)  loss_ce_0_unscaled: 1.0931 (1.1032)  loss_bbox_0_unscaled: 0.0892 (0.0868)  loss_giou_0_unscaled: 0.3225 (0.3273)  cardinality_error_0_unscaled: 0.6250 (0.6875)  loss_ce_1_unscaled: 0.9181 (0.9416)  loss_bbox_1_unscaled: 0.0978 (0.0923)  loss_giou_1_unscaled: 0.3484 (0.3476)  cardinality_error_1_unscaled: 0.6250 (0.6875)  loss_ce_enc_unscaled: 1.0764 (1.0653)  loss_bbox_enc_unscaled: 0.1111 (0.1088)  loss_giou_enc_unscaled: 0.3794 (0.3901)  cardinality_error_enc_unscaled: 0.6250 (0.6875)
# Test:  [ 0/12]  eta: 0:00:18  class_error: 0.00  loss: 7.6352 (7.6352)  loss_ce: 0.7461 (0.7461)  loss_bbox: 0.4045 (0.4045)  loss_giou: 0.6339 (0.6339)  loss_ce_0: 1.0703 (1.0703)  loss_bbox_0: 0.3833 (0.3833)  loss_giou_0: 0.5604 (0.5604)  loss_ce_1: 0.7734 (0.7734)  loss_bbox_1: 0.4304 (0.4304)  loss_giou_1: 0.6772 (0.6772)  loss_ce_enc: 1.2031 (1.2031)  loss_bbox_enc: 0.3109 (0.3109)  loss_giou_enc: 0.4416 (0.4416)  loss_ce_unscaled: 0.7461 (0.7461)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0809 (0.0809)  loss_giou_unscaled: 0.3169 (0.3169)  cardinality_error_unscaled: 1.0000 (1.0000)  loss_ce_0_unscaled: 1.0703 (1.0703)  loss_bbox_0_unscaled: 0.0767 (0.0767)  loss_giou_0_unscaled: 0.2802 (0.2802)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.7734 (0.7734)  loss_bbox_1_unscaled: 0.0861 (0.0861)  loss_giou_1_unscaled: 0.3386 (0.3386)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_enc_unscaled: 1.2031 (1.2031)  loss_bbox_enc_unscaled: 0.0622 (0.0622)  loss_giou_enc_unscaled: 0.2208 (0.2208)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 1.5229  data: 0.9887  max mem: 12923
# Test:  [10/12]  eta: 0:00:01  class_error: 100.00  loss: 6.9508 (5.6651)  loss_ce: 0.7031 (0.6464)  loss_bbox: 0.3052 (0.2925)  loss_giou: 0.6073 (0.4913)  loss_ce_0: 1.0078 (0.7536)  loss_bbox_0: 0.2947 (0.2093)  loss_giou_0: 0.5479 (0.4030)  loss_ce_1: 0.7734 (0.6778)  loss_bbox_1: 0.2250 (0.2633)  loss_giou_1: 0.5240 (0.4521)  loss_ce_enc: 1.0234 (0.8801)  loss_bbox_enc: 0.2739 (0.2083)  loss_giou_enc: 0.4416 (0.3874)  loss_ce_unscaled: 0.7031 (0.6464)  class_error_unscaled: 0.0000 (36.3636)  loss_bbox_unscaled: 0.0610 (0.0585)  loss_giou_unscaled: 0.3036 (0.2457)  cardinality_error_unscaled: 1.0000 (0.7159)  loss_ce_0_unscaled: 1.0078 (0.7536)  loss_bbox_0_unscaled: 0.0589 (0.0419)  loss_giou_0_unscaled: 0.2739 (0.2015)  cardinality_error_0_unscaled: 1.0000 (0.7159)  loss_ce_1_unscaled: 0.7734 (0.6778)  loss_bbox_1_unscaled: 0.0450 (0.0527)  loss_giou_1_unscaled: 0.2620 (0.2261)  cardinality_error_1_unscaled: 1.0000 (0.7159)  loss_ce_enc_unscaled: 1.0234 (0.8801)  loss_bbox_enc_unscaled: 0.0548 (0.0417)  loss_giou_enc_unscaled: 0.2208 (0.1937)  cardinality_error_enc_unscaled: 1.0000 (0.7159)  time: 0.6476  data: 0.2176  max mem: 12923
# Test:  [11/12]  eta: 0:00:00  class_error: 100.00  loss: 6.2291 (5.2135)  loss_ce: 0.6641 (0.5971)  loss_bbox: 0.2296 (0.2681)  loss_giou: 0.4885 (0.4504)  loss_ce_0: 0.9375 (0.6943)  loss_bbox_0: 0.1730 (0.1918)  loss_giou_0: 0.4239 (0.3694)  loss_ce_1: 0.6992 (0.6290)  loss_bbox_1: 0.2243 (0.2414)  loss_giou_1: 0.4819 (0.4145)  loss_ce_enc: 0.9922 (0.8114)  loss_bbox_enc: 0.1692 (0.1909)  loss_giou_enc: 0.4176 (0.3551)  loss_ce_unscaled: 0.6641 (0.5971)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0459 (0.0536)  loss_giou_unscaled: 0.2442 (0.2252)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 0.9375 (0.6943)  loss_bbox_0_unscaled: 0.0346 (0.0384)  loss_giou_0_unscaled: 0.2119 (0.1847)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 0.6992 (0.6290)  loss_bbox_1_unscaled: 0.0449 (0.0483)  loss_giou_1_unscaled: 0.2409 (0.2072)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 0.9922 (0.8114)  loss_bbox_enc_unscaled: 0.0338 (0.0382)  loss_giou_enc_unscaled: 0.2088 (0.1775)  cardinality_error_enc_unscaled: 1.0000 (0.6562)  time: 0.5992  data: 0.2004  max mem: 12923
# Test: Total time: 0:00:07 (0.6055 s / it)
# Averaged stats: class_error: 100.00  loss: 6.2291 (5.2135)  loss_ce: 0.6641 (0.5971)  loss_bbox: 0.2296 (0.2681)  loss_giou: 0.4885 (0.4504)  loss_ce_0: 0.9375 (0.6943)  loss_bbox_0: 0.1730 (0.1918)  loss_giou_0: 0.4239 (0.3694)  loss_ce_1: 0.6992 (0.6290)  loss_bbox_1: 0.2243 (0.2414)  loss_giou_1: 0.4819 (0.4145)  loss_ce_enc: 0.9922 (0.8114)  loss_bbox_enc: 0.1692 (0.1909)  loss_giou_enc: 0.4176 (0.3551)  loss_ce_unscaled: 0.6641 (0.5971)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0459 (0.0536)  loss_giou_unscaled: 0.2442 (0.2252)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 0.9375 (0.6943)  loss_bbox_0_unscaled: 0.0346 (0.0384)  loss_giou_0_unscaled: 0.2119 (0.1847)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 0.6992 (0.6290)  loss_bbox_1_unscaled: 0.0449 (0.0483)  loss_giou_1_unscaled: 0.2409 (0.2072)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 0.9922 (0.8114)  loss_bbox_enc_unscaled: 0.0338 (0.0382)  loss_giou_enc_unscaled: 0.2088 (0.1775)  cardinality_error_enc_unscaled: 1.0000 (0.6562)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.601
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.228
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.414
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.473
# Test:  [ 0/12]  eta: 0:00:17  class_error: 0.00  loss: 7.5502 (7.5502)  loss_ce: 0.8164 (0.8164)  loss_bbox: 0.3508 (0.3508)  loss_giou: 0.6131 (0.6131)  loss_ce_0: 1.0859 (1.0859)  loss_bbox_0: 0.3466 (0.3466)  loss_giou_0: 0.5313 (0.5313)  loss_ce_1: 0.8086 (0.8086)  loss_bbox_1: 0.4373 (0.4373)  loss_giou_1: 0.6339 (0.6339)  loss_ce_enc: 1.2109 (1.2109)  loss_bbox_enc: 0.2909 (0.2909)  loss_giou_enc: 0.4246 (0.4246)  loss_ce_unscaled: 0.8164 (0.8164)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0702 (0.0702)  loss_giou_unscaled: 0.3065 (0.3065)  cardinality_error_unscaled: 1.0000 (1.0000)  loss_ce_0_unscaled: 1.0859 (1.0859)  loss_bbox_0_unscaled: 0.0693 (0.0693)  loss_giou_0_unscaled: 0.2656 (0.2656)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.8086 (0.8086)  loss_bbox_1_unscaled: 0.0875 (0.0875)  loss_giou_1_unscaled: 0.3169 (0.3169)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_enc_unscaled: 1.2109 (1.2109)  loss_bbox_enc_unscaled: 0.0582 (0.0582)  loss_giou_enc_unscaled: 0.2123 (0.2123)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 1.4451  data: 0.9286  max mem: 12923
# Test:  [10/12]  eta: 0:00:01  class_error: 100.00  loss: 6.7661 (5.5621)  loss_ce: 0.7070 (0.6387)  loss_bbox: 0.3053 (0.2668)  loss_giou: 0.5442 (0.4710)  loss_ce_0: 1.0234 (0.7504)  loss_bbox_0: 0.2697 (0.2023)  loss_giou_0: 0.5238 (0.3940)  loss_ce_1: 0.7969 (0.6651)  loss_bbox_1: 0.2395 (0.2569)  loss_giou_1: 0.4905 (0.4546)  loss_ce_enc: 1.0312 (0.8730)  loss_bbox_enc: 0.2547 (0.2071)  loss_giou_enc: 0.4246 (0.3821)  loss_ce_unscaled: 0.7070 (0.6387)  class_error_unscaled: 0.0000 (36.3636)  loss_bbox_unscaled: 0.0611 (0.0534)  loss_giou_unscaled: 0.2721 (0.2355)  cardinality_error_unscaled: 1.0000 (0.7159)  loss_ce_0_unscaled: 1.0234 (0.7504)  loss_bbox_0_unscaled: 0.0539 (0.0405)  loss_giou_0_unscaled: 0.2619 (0.1970)  cardinality_error_0_unscaled: 1.0000 (0.7159)  loss_ce_1_unscaled: 0.7969 (0.6651)  loss_bbox_1_unscaled: 0.0479 (0.0514)  loss_giou_1_unscaled: 0.2452 (0.2273)  cardinality_error_1_unscaled: 1.0000 (0.7159)  loss_ce_enc_unscaled: 1.0312 (0.8730)  loss_bbox_enc_unscaled: 0.0509 (0.0414)  loss_giou_enc_unscaled: 0.2123 (0.1910)  cardinality_error_enc_unscaled: 1.0000 (0.7159)  time: 0.5877  data: 0.2091  max mem: 12923
# Test:  [11/12]  eta: 0:00:00  class_error: 100.00  loss: 6.2935 (5.1165)  loss_ce: 0.6719 (0.5894)  loss_bbox: 0.2258 (0.2445)  loss_giou: 0.4924 (0.4318)  loss_ce_0: 0.9648 (0.6911)  loss_bbox_0: 0.1693 (0.1854)  loss_giou_0: 0.4349 (0.3611)  loss_ce_1: 0.7344 (0.6161)  loss_bbox_1: 0.2242 (0.2355)  loss_giou_1: 0.4826 (0.4167)  loss_ce_enc: 0.9805 (0.8046)  loss_bbox_enc: 0.1626 (0.1899)  loss_giou_enc: 0.4181 (0.3502)  loss_ce_unscaled: 0.6719 (0.5894)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0452 (0.0489)  loss_giou_unscaled: 0.2462 (0.2159)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 0.9648 (0.6911)  loss_bbox_0_unscaled: 0.0339 (0.0371)  loss_giou_0_unscaled: 0.2174 (0.1806)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 0.7344 (0.6161)  loss_bbox_1_unscaled: 0.0448 (0.0471)  loss_giou_1_unscaled: 0.2413 (0.2084)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 0.9805 (0.8046)  loss_bbox_enc_unscaled: 0.0325 (0.0380)  loss_giou_enc_unscaled: 0.2091 (0.1751)  cardinality_error_enc_unscaled: 1.0000 (0.6562)  time: 0.5448  data: 0.1924  max mem: 12923
# Test: Total time: 0:00:06 (0.5489 s / it)
# Averaged stats: class_error: 100.00  loss: 6.2935 (5.1165)  loss_ce: 0.6719 (0.5894)  loss_bbox: 0.2258 (0.2445)  loss_giou: 0.4924 (0.4318)  loss_ce_0: 0.9648 (0.6911)  loss_bbox_0: 0.1693 (0.1854)  loss_giou_0: 0.4349 (0.3611)  loss_ce_1: 0.7344 (0.6161)  loss_bbox_1: 0.2242 (0.2355)  loss_giou_1: 0.4826 (0.4167)  loss_ce_enc: 0.9805 (0.8046)  loss_bbox_enc: 0.1626 (0.1899)  loss_giou_enc: 0.4181 (0.3502)  loss_ce_unscaled: 0.6719 (0.5894)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0452 (0.0489)  loss_giou_unscaled: 0.2462 (0.2159)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 0.9648 (0.6911)  loss_bbox_0_unscaled: 0.0339 (0.0371)  loss_giou_0_unscaled: 0.2174 (0.1806)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 0.7344 (0.6161)  loss_bbox_1_unscaled: 0.0448 (0.0471)  loss_giou_1_unscaled: 0.2413 (0.2084)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 0.9805 (0.8046)  loss_bbox_enc_unscaled: 0.0325 (0.0380)  loss_giou_enc_unscaled: 0.2091 (0.1751)  cardinality_error_enc_unscaled: 1.0000 (0.6562)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.221
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.606
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.414
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.455
# Early stopping: Current mAP (max(regular, EMA)): 0.2245, Best: 0.1473, Diff: 0.0772, Min delta: 0.001
# Grad accum steps:  2
# Total batch size:  16
# LENGTH OF DATA LOADER: 38
# Epoch: [2]  [ 0/38]  eta: 0:05:05  lr: 0.000100  class_error: 0.00  loss: 11.8025 (11.8025)  loss_ce: 0.9236 (0.9236)  loss_bbox: 0.6904 (0.6904)  loss_giou: 1.2174 (1.2174)  loss_ce_0: 0.7842 (0.7842)  loss_bbox_0: 0.9539 (0.9539)  loss_giou_0: 1.4519 (1.4519)  loss_ce_1: 0.9542 (0.9542)  loss_bbox_1: 0.6340 (0.6340)  loss_giou_1: 1.1875 (1.1875)  loss_ce_enc: 0.8883 (0.8883)  loss_bbox_enc: 0.7995 (0.7995)  loss_giou_enc: 1.3176 (1.3176)  loss_ce_unscaled: 0.9236 (0.9236)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.1381 (0.1381)  loss_giou_unscaled: 0.6087 (0.6087)  cardinality_error_unscaled: 0.3750 (0.3750)  loss_ce_0_unscaled: 0.7842 (0.7842)  loss_bbox_0_unscaled: 0.1908 (0.1908)  loss_giou_0_unscaled: 0.7260 (0.7260)  cardinality_error_0_unscaled: 0.3750 (0.3750)  loss_ce_1_unscaled: 0.9542 (0.9542)  loss_bbox_1_unscaled: 0.1268 (0.1268)  loss_giou_1_unscaled: 0.5938 (0.5938)  cardinality_error_1_unscaled: 0.3750 (0.3750)  loss_ce_enc_unscaled: 0.8883 (0.8883)  loss_bbox_enc_unscaled: 0.1599 (0.1599)  loss_giou_enc_unscaled: 0.6588 (0.6588)  cardinality_error_enc_unscaled: 0.3750 (0.3750)  time: 8.0379  data: 2.3046  max mem: 12923
# Epoch: [2]  [10/38]  eta: 0:02:45  lr: 0.000100  class_error: 0.00  loss: 7.6352 (8.0357)  loss_ce: 0.8489 (0.8331)  loss_bbox: 0.4180 (0.4097)  loss_giou: 0.6376 (0.6651)  loss_ce_0: 1.0926 (1.0826)  loss_bbox_0: 0.3163 (0.3481)  loss_giou_0: 0.5695 (0.5930)  loss_ce_1: 0.8795 (0.8651)  loss_bbox_1: 0.3732 (0.3938)  loss_giou_1: 0.6225 (0.6712)  loss_ce_enc: 1.1186 (1.0985)  loss_bbox_enc: 0.3452 (0.4044)  loss_giou_enc: 0.6052 (0.6711)  loss_ce_unscaled: 0.8489 (0.8331)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0836 (0.0819)  loss_giou_unscaled: 0.3188 (0.3325)  cardinality_error_unscaled: 0.6250 (0.6136)  loss_ce_0_unscaled: 1.0926 (1.0826)  loss_bbox_0_unscaled: 0.0633 (0.0696)  loss_giou_0_unscaled: 0.2847 (0.2965)  cardinality_error_0_unscaled: 0.6250 (0.6136)  loss_ce_1_unscaled: 0.8795 (0.8651)  loss_bbox_1_unscaled: 0.0746 (0.0788)  loss_giou_1_unscaled: 0.3113 (0.3356)  cardinality_error_1_unscaled: 0.6250 (0.6136)  loss_ce_enc_unscaled: 1.1186 (1.0985)  loss_bbox_enc_unscaled: 0.0690 (0.0809)  loss_giou_enc_unscaled: 0.3026 (0.3355)  cardinality_error_enc_unscaled: 0.6250 (0.6136)  time: 5.9283  data: 0.2389  max mem: 12923
# Epoch: [2]  [20/38]  eta: 0:01:44  lr: 0.000100  class_error: 0.00  loss: 7.4409 (7.8792)  loss_ce: 0.8170 (0.8292)  loss_bbox: 0.3910 (0.4245)  loss_giou: 0.5979 (0.6358)  loss_ce_0: 1.1000 (1.1217)  loss_bbox_0: 0.2688 (0.3201)  loss_giou_0: 0.4655 (0.5311)  loss_ce_1: 0.8551 (0.8699)  loss_bbox_1: 0.3732 (0.4051)  loss_giou_1: 0.5960 (0.6315)  loss_ce_enc: 1.1428 (1.1386)  loss_bbox_enc: 0.3115 (0.3734)  loss_giou_enc: 0.5065 (0.5984)  loss_ce_unscaled: 0.8170 (0.8292)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0782 (0.0849)  loss_giou_unscaled: 0.2990 (0.3179)  cardinality_error_unscaled: 0.6250 (0.5833)  loss_ce_0_unscaled: 1.1000 (1.1217)  loss_bbox_0_unscaled: 0.0538 (0.0640)  loss_giou_0_unscaled: 0.2328 (0.2656)  cardinality_error_0_unscaled: 0.6250 (0.5833)  loss_ce_1_unscaled: 0.8551 (0.8699)  loss_bbox_1_unscaled: 0.0746 (0.0810)  loss_giou_1_unscaled: 0.2980 (0.3157)  cardinality_error_1_unscaled: 0.6250 (0.5833)  loss_ce_enc_unscaled: 1.1428 (1.1386)  loss_bbox_enc_unscaled: 0.0623 (0.0747)  loss_giou_enc_unscaled: 0.2533 (0.2992)  cardinality_error_enc_unscaled: 0.6250 (0.5833)  time: 5.6883  data: 0.0345  max mem: 12923
# Epoch: [2]  [30/38]  eta: 0:00:46  lr: 0.000100  class_error: 0.00  loss: 7.6367 (8.1394)  loss_ce: 0.8170 (0.8224)  loss_bbox: 0.4610 (0.4455)  loss_giou: 0.5980 (0.6737)  loss_ce_0: 1.0773 (1.0744)  loss_bbox_0: 0.2849 (0.3685)  loss_giou_0: 0.4801 (0.5935)  loss_ce_1: 0.8255 (0.8475)  loss_bbox_1: 0.4292 (0.4477)  loss_giou_1: 0.5986 (0.6871)  loss_ce_enc: 1.1188 (1.0923)  loss_bbox_enc: 0.3594 (0.4249)  loss_giou_enc: 0.5264 (0.6620)  loss_ce_unscaled: 0.8170 (0.8224)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0922 (0.0891)  loss_giou_unscaled: 0.2990 (0.3368)  cardinality_error_unscaled: 0.6250 (0.6129)  loss_ce_0_unscaled: 1.0773 (1.0744)  loss_bbox_0_unscaled: 0.0570 (0.0737)  loss_giou_0_unscaled: 0.2400 (0.2968)  cardinality_error_0_unscaled: 0.6250 (0.6129)  loss_ce_1_unscaled: 0.8255 (0.8475)  loss_bbox_1_unscaled: 0.0858 (0.0895)  loss_giou_1_unscaled: 0.2993 (0.3436)  cardinality_error_1_unscaled: 0.6250 (0.6129)  loss_ce_enc_unscaled: 1.1188 (1.0923)  loss_bbox_enc_unscaled: 0.0719 (0.0850)  loss_giou_enc_unscaled: 0.2632 (0.3310)  cardinality_error_enc_unscaled: 0.6250 (0.6129)  time: 5.6749  data: 0.0390  max mem: 12923
# Epoch: [2]  [37/38]  eta: 0:00:05  lr: 0.000100  class_error: 0.00  loss: 7.7144 (8.0808)  loss_ce: 0.7668 (0.8079)  loss_bbox: 0.4237 (0.4389)  loss_giou: 0.6755 (0.6864)  loss_ce_0: 0.9988 (1.0533)  loss_bbox_0: 0.3397 (0.3682)  loss_giou_0: 0.5579 (0.5996)  loss_ce_1: 0.7911 (0.8358)  loss_bbox_1: 0.4219 (0.4356)  loss_giou_1: 0.6806 (0.6882)  loss_ce_enc: 1.0725 (1.0820)  loss_bbox_enc: 0.3768 (0.4226)  loss_giou_enc: 0.5765 (0.6623)  loss_ce_unscaled: 0.7668 (0.8079)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0847 (0.0878)  loss_giou_unscaled: 0.3377 (0.3432)  cardinality_error_unscaled: 0.6250 (0.6250)  loss_ce_0_unscaled: 0.9988 (1.0533)  loss_bbox_0_unscaled: 0.0679 (0.0736)  loss_giou_0_unscaled: 0.2790 (0.2998)  cardinality_error_0_unscaled: 0.6250 (0.6250)  loss_ce_1_unscaled: 0.7911 (0.8358)  loss_bbox_1_unscaled: 0.0844 (0.0871)  loss_giou_1_unscaled: 0.3403 (0.3441)  cardinality_error_1_unscaled: 0.6250 (0.6250)  loss_ce_enc_unscaled: 1.0725 (1.0820)  loss_bbox_enc_unscaled: 0.0754 (0.0845)  loss_giou_enc_unscaled: 0.2883 (0.3311)  cardinality_error_enc_unscaled: 0.6250 (0.6250)  time: 5.6743  data: 0.0375  max mem: 12923
# Epoch: [2] Total time: 0:03:38 (5.7587 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 7.7144 (8.0808)  loss_ce: 0.7668 (0.8079)  loss_bbox: 0.4237 (0.4389)  loss_giou: 0.6755 (0.6864)  loss_ce_0: 0.9988 (1.0533)  loss_bbox_0: 0.3397 (0.3682)  loss_giou_0: 0.5579 (0.5996)  loss_ce_1: 0.7911 (0.8358)  loss_bbox_1: 0.4219 (0.4356)  loss_giou_1: 0.6806 (0.6882)  loss_ce_enc: 1.0725 (1.0820)  loss_bbox_enc: 0.3768 (0.4226)  loss_giou_enc: 0.5765 (0.6623)  loss_ce_unscaled: 0.7668 (0.8079)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0847 (0.0878)  loss_giou_unscaled: 0.3377 (0.3432)  cardinality_error_unscaled: 0.6250 (0.6250)  loss_ce_0_unscaled: 0.9988 (1.0533)  loss_bbox_0_unscaled: 0.0679 (0.0736)  loss_giou_0_unscaled: 0.2790 (0.2998)  cardinality_error_0_unscaled: 0.6250 (0.6250)  loss_ce_1_unscaled: 0.7911 (0.8358)  loss_bbox_1_unscaled: 0.0844 (0.0871)  loss_giou_1_unscaled: 0.3403 (0.3441)  cardinality_error_1_unscaled: 0.6250 (0.6250)  loss_ce_enc_unscaled: 1.0725 (1.0820)  loss_bbox_enc_unscaled: 0.0754 (0.0845)  loss_giou_enc_unscaled: 0.2883 (0.3311)  cardinality_error_enc_unscaled: 0.6250 (0.6250)
# ...
# Epoch: [31]  [30/38]  eta: 0:00:46  lr: 0.000100  class_error: 0.00  loss: 5.3643 (4.8874)  loss_ce: 0.6049 (0.5418)  loss_bbox: 0.2431 (0.2406)  loss_giou: 0.3904 (0.3616)  loss_ce_0: 0.5947 (0.5759)  loss_bbox_0: 0.2343 (0.2426)  loss_giou_0: 0.3704 (0.3607)  loss_ce_1: 0.6013 (0.5501)  loss_bbox_1: 0.2492 (0.2417)  loss_giou_1: 0.3891 (0.3605)  loss_ce_enc: 0.6422 (0.6420)  loss_bbox_enc: 0.2911 (0.3273)  loss_giou_enc: 0.4878 (0.4425)  loss_ce_unscaled: 0.6049 (0.5418)  class_error_unscaled: 0.0000 (3.2258)  loss_bbox_unscaled: 0.0486 (0.0481)  loss_giou_unscaled: 0.1952 (0.1808)  cardinality_error_unscaled: 0.7500 (0.6935)  loss_ce_0_unscaled: 0.5947 (0.5759)  loss_bbox_0_unscaled: 0.0469 (0.0485)  loss_giou_0_unscaled: 0.1852 (0.1803)  cardinality_error_0_unscaled: 0.7500 (0.6935)  loss_ce_1_unscaled: 0.6013 (0.5501)  loss_bbox_1_unscaled: 0.0498 (0.0483)  loss_giou_1_unscaled: 0.1945 (0.1802)  cardinality_error_1_unscaled: 0.7500 (0.6935)  loss_ce_enc_unscaled: 0.6422 (0.6420)  loss_bbox_enc_unscaled: 0.0582 (0.0655)  loss_giou_enc_unscaled: 0.2439 (0.2212)  cardinality_error_enc_unscaled: 0.7500 (0.6935)  time: 5.7467  data: 0.0368  max mem: 12925
# Epoch: [31]  [37/38]  eta: 0:00:05  lr: 0.000100  class_error: 0.00  loss: 4.5611 (4.9412)  loss_ce: 0.5234 (0.5438)  loss_bbox: 0.2388 (0.2457)  loss_giou: 0.3805 (0.3712)  loss_ce_0: 0.5247 (0.5780)  loss_bbox_0: 0.2299 (0.2473)  loss_giou_0: 0.3541 (0.3691)  loss_ce_1: 0.5205 (0.5505)  loss_bbox_1: 0.2350 (0.2466)  loss_giou_1: 0.3812 (0.3719)  loss_ce_enc: 0.5990 (0.6407)  loss_bbox_enc: 0.2911 (0.3273)  loss_giou_enc: 0.4449 (0.4490)  loss_ce_unscaled: 0.5234 (0.5438)  class_error_unscaled: 0.0000 (2.6316)  loss_bbox_unscaled: 0.0478 (0.0491)  loss_giou_unscaled: 0.1903 (0.1856)  cardinality_error_unscaled: 0.7500 (0.7072)  loss_ce_0_unscaled: 0.5247 (0.5780)  loss_bbox_0_unscaled: 0.0460 (0.0495)  loss_giou_0_unscaled: 0.1770 (0.1846)  cardinality_error_0_unscaled: 0.7500 (0.7072)  loss_ce_1_unscaled: 0.5205 (0.5505)  loss_bbox_1_unscaled: 0.0470 (0.0493)  loss_giou_1_unscaled: 0.1906 (0.1860)  cardinality_error_1_unscaled: 0.7500 (0.7072)  loss_ce_enc_unscaled: 0.5990 (0.6407)  loss_bbox_enc_unscaled: 0.0582 (0.0655)  loss_giou_enc_unscaled: 0.2225 (0.2245)  cardinality_error_enc_unscaled: 0.7500 (0.7072)  time: 5.6981  data: 0.0367  max mem: 12925
# Epoch: [31] Total time: 0:03:39 (5.7751 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 4.5611 (4.9412)  loss_ce: 0.5234 (0.5438)  loss_bbox: 0.2388 (0.2457)  loss_giou: 0.3805 (0.3712)  loss_ce_0: 0.5247 (0.5780)  loss_bbox_0: 0.2299 (0.2473)  loss_giou_0: 0.3541 (0.3691)  loss_ce_1: 0.5205 (0.5505)  loss_bbox_1: 0.2350 (0.2466)  loss_giou_1: 0.3812 (0.3719)  loss_ce_enc: 0.5990 (0.6407)  loss_bbox_enc: 0.2911 (0.3273)  loss_giou_enc: 0.4449 (0.4490)  loss_ce_unscaled: 0.5234 (0.5438)  class_error_unscaled: 0.0000 (2.6316)  loss_bbox_unscaled: 0.0478 (0.0491)  loss_giou_unscaled: 0.1903 (0.1856)  cardinality_error_unscaled: 0.7500 (0.7072)  loss_ce_0_unscaled: 0.5247 (0.5780)  loss_bbox_0_unscaled: 0.0460 (0.0495)  loss_giou_0_unscaled: 0.1770 (0.1846)  cardinality_error_0_unscaled: 0.7500 (0.7072)  loss_ce_1_unscaled: 0.5205 (0.5505)  loss_bbox_1_unscaled: 0.0470 (0.0493)  loss_giou_1_unscaled: 0.1906 (0.1860)  cardinality_error_1_unscaled: 0.7500 (0.7072)  loss_ce_enc_unscaled: 0.5990 (0.6407)  loss_bbox_enc_unscaled: 0.0582 (0.0655)  loss_giou_enc_unscaled: 0.2225 (0.2245)  cardinality_error_enc_unscaled: 0.7500 (0.7072)
# Test:  [ 0/12]  eta: 0:00:16  class_error: 0.00  loss: 6.0553 (6.0553)  loss_ce: 0.6289 (0.6289)  loss_bbox: 0.3078 (0.3078)  loss_giou: 0.5315 (0.5315)  loss_ce_0: 0.6484 (0.6484)  loss_bbox_0: 0.2936 (0.2936)  loss_giou_0: 0.5171 (0.5171)  loss_ce_1: 0.6289 (0.6289)  loss_bbox_1: 0.3302 (0.3302)  loss_giou_1: 0.5349 (0.5349)  loss_ce_enc: 0.7891 (0.7891)  loss_bbox_enc: 0.3288 (0.3288)  loss_giou_enc: 0.5161 (0.5161)  loss_ce_unscaled: 0.6289 (0.6289)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0616 (0.0616)  loss_giou_unscaled: 0.2657 (0.2657)  cardinality_error_unscaled: 1.0000 (1.0000)  loss_ce_0_unscaled: 0.6484 (0.6484)  loss_bbox_0_unscaled: 0.0587 (0.0587)  loss_giou_0_unscaled: 0.2585 (0.2585)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.6289 (0.6289)  loss_bbox_1_unscaled: 0.0660 (0.0660)  loss_giou_1_unscaled: 0.2674 (0.2674)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_enc_unscaled: 0.7891 (0.7891)  loss_bbox_enc_unscaled: 0.0658 (0.0658)  loss_giou_enc_unscaled: 0.2581 (0.2581)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 1.3866  data: 0.9467  max mem: 12925
# Test:  [10/12]  eta: 0:00:01  class_error: 100.00  loss: 5.8629 (4.5791)  loss_ce: 0.6211 (0.5443)  loss_bbox: 0.2477 (0.2215)  loss_giou: 0.5315 (0.3941)  loss_ce_0: 0.5352 (0.5029)  loss_bbox_0: 0.2480 (0.2185)  loss_giou_0: 0.5171 (0.3948)  loss_ce_1: 0.6133 (0.5283)  loss_bbox_1: 0.2425 (0.2270)  loss_giou_1: 0.5349 (0.3888)  loss_ce_enc: 0.5703 (0.5114)  loss_bbox_enc: 0.2783 (0.2356)  loss_giou_enc: 0.5161 (0.4118)  loss_ce_unscaled: 0.6211 (0.5443)  class_error_unscaled: 0.0000 (36.3636)  loss_bbox_unscaled: 0.0495 (0.0443)  loss_giou_unscaled: 0.2657 (0.1970)  cardinality_error_unscaled: 1.0000 (0.7159)  loss_ce_0_unscaled: 0.5352 (0.5029)  loss_bbox_0_unscaled: 0.0496 (0.0437)  loss_giou_0_unscaled: 0.2585 (0.1974)  cardinality_error_0_unscaled: 1.0000 (0.7159)  loss_ce_1_unscaled: 0.6133 (0.5283)  loss_bbox_1_unscaled: 0.0485 (0.0454)  loss_giou_1_unscaled: 0.2674 (0.1944)  cardinality_error_1_unscaled: 1.0000 (0.7159)  loss_ce_enc_unscaled: 0.5703 (0.5114)  loss_bbox_enc_unscaled: 0.0557 (0.0471)  loss_giou_enc_unscaled: 0.2581 (0.2059)  cardinality_error_enc_unscaled: 1.0000 (0.7159)  time: 0.5706  data: 0.2139  max mem: 12925
# Test:  [11/12]  eta: 0:00:00  class_error: 100.00  loss: 5.0642 (4.1992)  loss_ce: 0.6094 (0.4990)  loss_bbox: 0.2460 (0.2031)  loss_giou: 0.4901 (0.3613)  loss_ce_0: 0.5312 (0.4617)  loss_bbox_0: 0.2282 (0.2003)  loss_giou_0: 0.5089 (0.3619)  loss_ce_1: 0.5664 (0.4845)  loss_bbox_1: 0.2400 (0.2081)  loss_giou_1: 0.4897 (0.3564)  loss_ce_enc: 0.5195 (0.4696)  loss_bbox_enc: 0.2458 (0.2160)  loss_giou_enc: 0.4800 (0.3774)  loss_ce_unscaled: 0.6094 (0.4990)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0492 (0.0406)  loss_giou_unscaled: 0.2450 (0.1806)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 0.5312 (0.4617)  loss_bbox_0_unscaled: 0.0456 (0.0401)  loss_giou_0_unscaled: 0.2544 (0.1809)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 0.5664 (0.4845)  loss_bbox_1_unscaled: 0.0480 (0.0416)  loss_giou_1_unscaled: 0.2449 (0.1782)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 0.5195 (0.4696)  loss_bbox_enc_unscaled: 0.0492 (0.0432)  loss_giou_enc_unscaled: 0.2400 (0.1887)  cardinality_error_enc_unscaled: 1.0000 (0.6562)  time: 0.5283  data: 0.1969  max mem: 12925
# Test: Total time: 0:00:06 (0.5326 s / it)
# Averaged stats: class_error: 100.00  loss: 5.0642 (4.1992)  loss_ce: 0.6094 (0.4990)  loss_bbox: 0.2460 (0.2031)  loss_giou: 0.4901 (0.3613)  loss_ce_0: 0.5312 (0.4617)  loss_bbox_0: 0.2282 (0.2003)  loss_giou_0: 0.5089 (0.3619)  loss_ce_1: 0.5664 (0.4845)  loss_bbox_1: 0.2400 (0.2081)  loss_giou_1: 0.4897 (0.3564)  loss_ce_enc: 0.5195 (0.4696)  loss_bbox_enc: 0.2458 (0.2160)  loss_giou_enc: 0.4800 (0.3774)  loss_ce_unscaled: 0.6094 (0.4990)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0492 (0.0406)  loss_giou_unscaled: 0.2450 (0.1806)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 0.5312 (0.4617)  loss_bbox_0_unscaled: 0.0456 (0.0401)  loss_giou_0_unscaled: 0.2544 (0.1809)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 0.5664 (0.4845)  loss_bbox_1_unscaled: 0.0480 (0.0416)  loss_giou_1_unscaled: 0.2449 (0.1782)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 0.5195 (0.4696)  loss_bbox_enc_unscaled: 0.0492 (0.0432)  loss_giou_enc_unscaled: 0.2400 (0.1887)  cardinality_error_enc_unscaled: 1.0000 (0.6562)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.672
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.326
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.352
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.505
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.508
# Test:  [ 0/12]  eta: 0:00:15  class_error: 0.00  loss: 5.6853 (5.6853)  loss_ce: 0.5664 (0.5664)  loss_bbox: 0.2951 (0.2951)  loss_giou: 0.5151 (0.5151)  loss_ce_0: 0.6211 (0.6211)  loss_bbox_0: 0.3155 (0.3155)  loss_giou_0: 0.4441 (0.4441)  loss_ce_1: 0.6289 (0.6289)  loss_bbox_1: 0.2553 (0.2553)  loss_giou_1: 0.4276 (0.4276)  loss_ce_enc: 0.7227 (0.7227)  loss_bbox_enc: 0.3632 (0.3632)  loss_giou_enc: 0.5303 (0.5303)  loss_ce_unscaled: 0.5664 (0.5664)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0590 (0.0590)  loss_giou_unscaled: 0.2576 (0.2576)  cardinality_error_unscaled: 1.0000 (1.0000)  loss_ce_0_unscaled: 0.6211 (0.6211)  loss_bbox_0_unscaled: 0.0631 (0.0631)  loss_giou_0_unscaled: 0.2220 (0.2220)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.6289 (0.6289)  loss_bbox_1_unscaled: 0.0511 (0.0511)  loss_giou_1_unscaled: 0.2138 (0.2138)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_enc_unscaled: 0.7227 (0.7227)  loss_bbox_enc_unscaled: 0.0726 (0.0726)  loss_giou_enc_unscaled: 0.2651 (0.2651)  cardinality_error_enc_unscaled: 1.0000 (1.0000)  time: 1.2971  data: 0.9155  max mem: 12925
# Test:  [10/12]  eta: 0:00:01  class_error: 100.00  loss: 5.1511 (4.7636)  loss_ce: 0.6094 (0.6729)  loss_bbox: 0.2114 (0.1929)  loss_giou: 0.5101 (0.3792)  loss_ce_0: 0.5898 (0.5646)  loss_bbox_0: 0.2173 (0.2001)  loss_giou_0: 0.4508 (0.3745)  loss_ce_1: 0.6289 (0.6376)  loss_bbox_1: 0.2080 (0.2060)  loss_giou_1: 0.4415 (0.3813)  loss_ce_enc: 0.5938 (0.5422)  loss_bbox_enc: 0.2261 (0.2235)  loss_giou_enc: 0.5088 (0.3888)  loss_ce_unscaled: 0.6094 (0.6729)  class_error_unscaled: 0.0000 (36.3636)  loss_bbox_unscaled: 0.0423 (0.0386)  loss_giou_unscaled: 0.2551 (0.1896)  cardinality_error_unscaled: 1.0000 (0.7159)  loss_ce_0_unscaled: 0.5898 (0.5646)  loss_bbox_0_unscaled: 0.0435 (0.0400)  loss_giou_0_unscaled: 0.2254 (0.1872)  cardinality_error_0_unscaled: 1.0000 (0.7159)  loss_ce_1_unscaled: 0.6289 (0.6376)  loss_bbox_1_unscaled: 0.0416 (0.0412)  loss_giou_1_unscaled: 0.2207 (0.1907)  cardinality_error_1_unscaled: 1.0000 (0.7159)  loss_ce_enc_unscaled: 0.5938 (0.5422)  loss_bbox_enc_unscaled: 0.0452 (0.0447)  loss_giou_enc_unscaled: 0.2544 (0.1944)  cardinality_error_enc_unscaled: 1.0000 (0.7159)  time: 0.5929  data: 0.1703  max mem: 12925
# Test:  [11/12]  eta: 0:00:00  class_error: 100.00  loss: 4.6445 (4.4331)  loss_ce: 0.5664 (0.6409)  loss_bbox: 0.2108 (0.1768)  loss_giou: 0.4422 (0.3476)  loss_ce_0: 0.5664 (0.5318)  loss_bbox_0: 0.2015 (0.1834)  loss_giou_0: 0.4441 (0.3432)  loss_ce_1: 0.5977 (0.6081)  loss_bbox_1: 0.2070 (0.1889)  loss_giou_1: 0.4276 (0.3496)  loss_ce_enc: 0.5781 (0.5016)  loss_bbox_enc: 0.2170 (0.2049)  loss_giou_enc: 0.4502 (0.3564)  loss_ce_unscaled: 0.5664 (0.6409)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0422 (0.0354)  loss_giou_unscaled: 0.2211 (0.1738)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 0.5664 (0.5318)  loss_bbox_0_unscaled: 0.0403 (0.0367)  loss_giou_0_unscaled: 0.2220 (0.1716)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 0.5977 (0.6081)  loss_bbox_1_unscaled: 0.0414 (0.0378)  loss_giou_1_unscaled: 0.2138 (0.1748)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 0.5781 (0.5016)  loss_bbox_enc_unscaled: 0.0434 (0.0410)  loss_giou_enc_unscaled: 0.2251 (0.1782)  cardinality_error_enc_unscaled: 1.0000 (0.6562)  time: 0.5496  data: 0.1569  max mem: 12925
# Test: Total time: 0:00:06 (0.5554 s / it)
# Averaged stats: class_error: 100.00  loss: 4.6445 (4.4331)  loss_ce: 0.5664 (0.6409)  loss_bbox: 0.2108 (0.1768)  loss_giou: 0.4422 (0.3476)  loss_ce_0: 0.5664 (0.5318)  loss_bbox_0: 0.2015 (0.1834)  loss_giou_0: 0.4441 (0.3432)  loss_ce_1: 0.5977 (0.6081)  loss_bbox_1: 0.2070 (0.1889)  loss_giou_1: 0.4276 (0.3496)  loss_ce_enc: 0.5781 (0.5016)  loss_bbox_enc: 0.2170 (0.2049)  loss_giou_enc: 0.4502 (0.3564)  loss_ce_unscaled: 0.5664 (0.6409)  class_error_unscaled: 0.0000 (41.6667)  loss_bbox_unscaled: 0.0422 (0.0354)  loss_giou_unscaled: 0.2211 (0.1738)  cardinality_error_unscaled: 1.0000 (0.6562)  loss_ce_0_unscaled: 0.5664 (0.5318)  loss_bbox_0_unscaled: 0.0403 (0.0367)  loss_giou_0_unscaled: 0.2220 (0.1716)  cardinality_error_0_unscaled: 1.0000 (0.6562)  loss_ce_1_unscaled: 0.5977 (0.6081)  loss_bbox_1_unscaled: 0.0414 (0.0378)  loss_giou_1_unscaled: 0.2138 (0.1748)  cardinality_error_1_unscaled: 1.0000 (0.6562)  loss_ce_enc_unscaled: 0.5781 (0.5016)  loss_bbox_enc_unscaled: 0.0434 (0.0410)  loss_giou_enc_unscaled: 0.2251 (0.1782)  cardinality_error_enc_unscaled: 1.0000 (0.6562)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.691
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.368
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.395
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.474
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.531
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.534
# Early stopping: Current mAP (max(regular, EMA)): 0.3657, Best: 0.3686, Diff: -0.0029, Min delta: 0.001
# Early stopping: No improvement in mAP for 10 epochs (best: 0.3686, current: 0.3657)
# Early stopping triggered: No improvement above 0.001 threshold for 10 epochs
# Early stopping requested, will complete current epoch and stop
# Early stopping requested, stopping at epoch 31
# Training time 2:04:53
# Results saved to /kaggle/working/output/results.json
# Results saved to /kaggle/working/output/metrics_plot.png
# Training completed successfully!
