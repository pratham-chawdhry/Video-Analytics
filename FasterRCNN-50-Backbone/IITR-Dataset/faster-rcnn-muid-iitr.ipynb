# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/muid-iitr-train-val-test-split/labels.csv
# /kaggle/input/muid-iitr-train-val-test-split/split_data/data.yaml
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_32.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_43.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_68.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_171.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/lp_52.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mn_5.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_203.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_41.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_143.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/ln_30.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_211.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hn_23.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_119.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_126.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_98.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mn_40.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_49.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_11.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_51.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/ln_75.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_77.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_4.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_36.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_97.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/lp_5.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/lp_16.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/ln_1.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_6.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hn_4.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_164.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/lp_86.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_120.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_44.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mn_18.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_88.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_108.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/lp_3.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_116.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_155.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_158.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_3.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/ln_44.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_1.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_84.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_158.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_96.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_121.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/ln_85.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_29.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_84.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_145.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_209.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_162.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/lp_102.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_194.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_176.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_116.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_56.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_1.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mn_12.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_107.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/ln_18.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_193.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_41.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mn_38.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/ln_63.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_30.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/lp_55.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_173.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mn_57.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_85.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/lp_57.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mn_60.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/ln_34.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_165.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_178.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/lp_127.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_73.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mn_42.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mn_21.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_106.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_142.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_119.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_207.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/en_19.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_89.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/lp_121.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/hp_22.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels/mp_20.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_119.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_4.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mn_5.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_85.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_120.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_84.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_22.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_209.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_88.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_158.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_56.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_77.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mn_57.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/lp_86.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/lp_52.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_96.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_84.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_49.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_207.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_119.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_51.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/ln_44.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_116.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_106.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_176.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_107.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_194.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/ln_63.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_73.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_41.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mn_38.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_41.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/ln_30.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_178.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_121.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mn_42.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_173.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_155.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/ln_34.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_116.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/lp_57.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_145.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/lp_16.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_11.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/lp_102.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_68.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_1.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/ln_1.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_165.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/ln_75.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/lp_121.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_203.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_162.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/lp_55.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/ln_18.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mn_12.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_97.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_3.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_211.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_143.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hn_23.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_30.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hn_4.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_126.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_44.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/lp_5.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_142.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_158.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mn_40.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/ln_85.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mn_21.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_1.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_43.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_98.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_171.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mn_60.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mn_18.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_164.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_36.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/lp_127.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_108.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_193.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_6.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/lp_3.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_32.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_20.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/en_19.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/mp_29.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images/hp_89.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_137.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_60.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mn_34.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hn_20.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_126.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_8.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_87.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_101.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_46.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_113.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_85.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_6.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_53.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_40.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_34.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_137.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_44.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_193.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_138.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_90.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_170.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_66.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_73.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_11.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_7.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_37.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_9.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_105.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mn_54.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_37.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_23.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_24.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_74.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_125.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_34.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_165.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_204.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_156.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_115.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_79.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_37.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mn_7.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_127.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_14.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_132.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mn_53.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_161.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_164.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_156.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mn_24.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mn_9.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_110.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_49.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_98.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_94.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_103.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_52.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_208.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_33.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_31.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_178.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_101.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_78.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_91.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_27.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_102.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_64.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_28.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mn_43.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hn_22.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_138.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_144.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_141.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mn_62.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_168.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_36.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_67.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_150.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_128.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_147.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_205.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_191.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_50.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_172.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_78.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_202.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_48.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_197.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_10.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_83.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_160.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_76.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_96.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_76.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_121.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hn_9.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_118.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_195.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_35.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_10.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_100.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_95.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_82.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_93.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_104.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_35.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_164.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_150.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_189.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_199.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mn_22.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_61.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_64.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_125.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_59.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hn_18.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_129.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_146.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_27.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_77.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_97.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_184.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_122.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_199.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hn_17.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_30.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_190.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_63.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_187.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mn_31.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_99.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_8.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_22.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_192.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_42.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_74.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_59.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_48.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_49.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_127.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_128.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_22.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_36.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_47.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_4.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_49.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_66.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_148.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_61.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_15.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mn_25.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_46.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_63.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_87.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_96.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_91.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_55.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_148.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_14.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_59.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_179.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_154.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_26.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_51.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_42.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_6.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_69.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hn_11.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_106.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_200.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_22.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/en_153.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/hp_53.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_108.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_122.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/mp_92.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/ln_23.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/labels/lp_72.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_48.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_76.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_34.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_91.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_138.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_113.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_23.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_106.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hn_22.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mn_34.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_8.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_14.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_22.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_44.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_96.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_148.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_101.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_72.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_99.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_46.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_77.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_59.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_60.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_48.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_37.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_6.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_46.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_170.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mn_25.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mn_7.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_42.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_59.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_78.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_91.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mn_43.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_179.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_95.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_160.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_47.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_73.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_137.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_67.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_49.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_24.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_74.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_96.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_53.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_82.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_6.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_37.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_187.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_8.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_22.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_148.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_10.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_63.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_4.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_78.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_98.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_79.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_76.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_53.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_127.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_101.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_193.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_150.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_192.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_121.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_27.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_37.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_156.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_122.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_205.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_33.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_49.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_31.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_129.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_141.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_69.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_27.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mn_62.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_97.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_138.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_118.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mn_22.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_85.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_122.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hn_9.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_74.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_125.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_204.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_208.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_36.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_10.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_59.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_190.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hn_11.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_202.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_150.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_125.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_127.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_52.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_153.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_164.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_165.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_115.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_184.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_137.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_154.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_23.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_172.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_87.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_103.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hn_18.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_147.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mn_53.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_199.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mn_31.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_83.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_51.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_63.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_104.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_64.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_128.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_195.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_22.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_144.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_66.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_164.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_128.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_66.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_64.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_49.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mn_54.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_197.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mn_9.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_92.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_87.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_100.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_90.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_189.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_132.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hn_20.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_11.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_108.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_7.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_110.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_34.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_40.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_61.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_93.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_28.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_199.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_102.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_30.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_94.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_50.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_146.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_161.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/en_26.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_42.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_61.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_200.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hn_17.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/lp_9.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_55.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_191.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_178.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_168.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_105.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_15.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/hp_35.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_156.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mp_126.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_35.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/mn_24.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_36.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/test/images/ln_14.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/ln_66.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mn_59.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_105.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_95.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mn_19.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/ln_71.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/en_146.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/ln_61.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_175.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/en_39.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/ln_57.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mp_32.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_73.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/en_14.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_31.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/en_27.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_26.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mp_33.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_2.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/ln_3.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_65.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_114.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/en_9.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_166.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_21.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hn_10.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mp_149.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mp_151.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/en_70.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_43.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mp_70.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_30.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mn_69.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mp_163.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mp_162.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mp_133.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_54.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_160.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/ln_48.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/ln_21.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/en_141.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/ln_56.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/en_55.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_106.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_49.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_149.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mp_103.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mn_13.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_48.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/en_149.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mn_2.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_101.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_82.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_12.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/ln_8.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/ln_43.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/mn_27.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/lp_47.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_181.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_157.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/en_82.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_81.txt
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels/hp_2.txt
# ...
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_44.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_5.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_94.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_133.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_83.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_85.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_58.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_47.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_84.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_86.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_14.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_117.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_112.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_69.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_65.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_24.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_163.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_55.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_26.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_70.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_82.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_182.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_61.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_99.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_12.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_57.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_80.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_95.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_69.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_147.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_28.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_135.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_76.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_20.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_78.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_167.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_150.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_74.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_94.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_67.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_19.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_23.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_32.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_123.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_47.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_6.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_62.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_173.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_29.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_48.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_129.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_54.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_108.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_187.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_43.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hn_5.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_55.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hn_10.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_89.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_96.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_114.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_197.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_9.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_79.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_63.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_87.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_68.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_146.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_8.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_160.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_5.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_27.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_30.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_42.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_25.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_15.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_66.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_73.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_33.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_88.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_71.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_65.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_51.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_61.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_35.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_52.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_60.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_108.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_79.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_2.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_84.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_21.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_5.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_104.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_157.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_81.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_71.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_56.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_139.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_21.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_104.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_104.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_105.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_33.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_149.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_118.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_109.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_158.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_166.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_14.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_10.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_6.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_73.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_98.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_13.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_92.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_205.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_110.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_79.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_115.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_77.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_15.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_19.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_163.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_16.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_142.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_24.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_157.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_117.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_195.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_69.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_89.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_194.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_19.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_206.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_103.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_50.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_58.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_31.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_14.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_145.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_139.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_134.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_65.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_118.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_72.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_138.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_4.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_2.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_111.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_152.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_180.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_196.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_151.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_132.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_180.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_71.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_53.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_51.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_56.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_171.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_10.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_71.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_151.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_45.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_86.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_50.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_175.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_61.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_58.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_100.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_29.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_76.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_78.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_95.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_82.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hn_8.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_41.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_60.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_89.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_39.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_4.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_33.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_41.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_76.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_1.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_106.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_135.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_129.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/ln_40.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_54.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/hp_163.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_101.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_133.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mp_9.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_64.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_12.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_87.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/lp_120.jpg
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/mn_59.png
# /kaggle/input/muid-iitr-train-val-test-split/split_data/train/images/en_111.png

# %%
# Upgrade PyTorch and Torchvision if needed
# !pip install --upgrade torch torchvision

# Install PIL (Pillow) and NumPy if not already present
# !pip install --upgrade pillow numpy

# If you need a specific version of Torchvision that supports the model you're using, specify it like this:
# !pip install --upgrade torch==2.0.0 torchvision==0.15.0
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Collecting torch
#   Downloading torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Collecting torchvision
#   Downloading torchvision-0.22.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch)
#   Downloading triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.0->torch) (75.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision) (2024.2.0)
# Downloading torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl (865.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 98.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 68.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 48.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 7.0 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 10.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 11.0 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 8.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 77.9 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 6.6 MB/s eta 0:00:00
# Downloading triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 10.4 MB/s eta 0:00:00
# Downloading torchvision-0.22.0-cp311-cp311-manylinux_2_28_x86_64.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 93.1 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 89.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.127
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu124
#     Uninstalling torch-2.5.1+cu124:
#       Successfully uninstalled torch-2.5.1+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu124
#     Uninstalling torchvision-0.20.1+cu124:
#       Successfully uninstalled torchvision-0.20.1+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.18 requires torch<2.6,>=1.10, but you have torch 2.7.0 which is incompatible.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.7.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 sympy-1.14.0 torch-2.7.0 torchvision-0.22.0 triton-3.3.0
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Collecting pillow
#   Downloading pillow-11.2.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Collecting numpy
#   Downloading numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.8 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp311-cp311-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 69.2 MB/s eta 0:00:00
# Downloading numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 86.4 MB/s eta 0:00:00
# Installing collected packages: pillow, numpy
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.5 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.5 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.5 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.5 which is incompatible.
# datasets 3.5.0 requires fsspec[http]<=2024.12.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# ydata-profiling 4.16.1 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.5 which is incompatible.
# catboost 1.2.7 requires numpy<2.0,>=1.16.0, but you have numpy 2.2.5 which is incompatible.
# nilearn 0.11.1 requires scikit-learn>=1.4.0, but you have scikit-learn 1.2.2 which is incompatible.
# matplotlib 3.7.5 requires numpy<2,>=1.20, but you have numpy 2.2.5 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.5, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.5 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.2.5 which is incompatible.
# pandas-gbq 0.26.1 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# bigframes 1.36.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# pytensor 2.27.1 requires numpy<2,>=1.17.0, but you have numpy 2.2.5 which is incompatible.
# ibis-framework 9.2.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# ibis-framework 9.2.0 requires toolz<1,>=0.11, but you have toolz 1.0.0 which is incompatible.
# langchain 0.3.18 requires numpy<2,>=1.26.4; python_version < "3.12", but you have numpy 2.2.5 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.5 which is incompatible.
# fastai 2.7.18 requires torch<2.6,>=1.10, but you have torch 2.7.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed numpy-2.2.5 pillow-11.2.1

# %%
import os
import numpy as np
import torch
import torch.utils.data
import torchvision
from torchvision import transforms
from PIL import Image

# ---------------------------
# Helper Functions
# ---------------------------
def read_yolo_labels(label_path, img_width, img_height):
    """
    Reads a YOLO-format label file and converts boxes from normalized (x_center, y_center, w, h)
    to absolute coordinates [xmin, ymin, xmax, ymax] (in pixels).
    Returns: boxes (list of lists) and labels (list of int).
    """
    boxes = []
    labels = []
    if not os.path.exists(label_path):
        return boxes, labels
    with open(label_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            cls = int(parts[0])
            x_center, y_center, w, h = map(float, parts[1:5])
            # Convert normalized coordinates to absolute
            x_center *= img_width
            y_center *= img_height
            w *= img_width
            h *= img_height
            xmin = x_center - w / 2
            ymin = y_center - h / 2
            xmax = x_center + w / 2
            ymax = y_center + h / 2
            boxes.append([xmin, ymin, xmax, ymax])
            labels.append(cls + 1)  # add 1 if 0 is reserved for background
    return boxes, labels

def compute_iou_np(box1, box2):
    """
    Compute IoU between two boxes in [xmin, ymin, xmax, ymax] format.
    """
    xi1 = max(box1[0], box2[0])
    yi1 = max(box1[1], box2[1])
    xi2 = min(box1[2], box2[2])
    yi2 = min(box1[3], box2[3])
    inter_width = max(0, xi2 - xi1)
    inter_height = max(0, yi2 - yi1)
    inter_area = inter_width * inter_height
    box1_area = (box1[2]-box1[0]) * (box1[3]-box1[1])
    box2_area = (box2[2]-box2[0]) * (box2[3]-box2[1])
    union_area = box1_area + box2_area - inter_area
    return inter_area / union_area if union_area > 0 else 0

# ---------------------------
# Custom Dataset for Faster R-CNN
# ---------------------------
class YoloDataset(torch.utils.data.Dataset):
    def __init__(self, images_dir, labels_dir, transforms=None):
        self.images_dir = images_dir
        self.labels_dir = labels_dir
        self.transforms = transforms
        self.image_files = sorted([f for f in os.listdir(images_dir) if f.lower().endswith(('.jpg', '.png', '.jpeg'))])
    
    def __getitem__(self, idx):
        # Load image
        img_filename = self.image_files[idx]
        img_path = os.path.join(self.images_dir, img_filename)
        img = Image.open(img_path).convert("RGB")
        img_width, img_height = img.size
        
        # Load label file with the same base name
        base = os.path.splitext(img_filename)[0]
        label_path = os.path.join(self.labels_dir, base + ".txt")
        boxes, labels = read_yolo_labels(label_path, img_width, img_height)
        
        # If no boxes were found, create empty tensors with the correct shape
        if len(boxes) == 0:
            boxes = torch.empty((0, 4), dtype=torch.float32)
            labels = torch.empty((0,), dtype=torch.int64)
        else:
            boxes = torch.as_tensor(boxes, dtype=torch.float32)
            labels = torch.as_tensor(labels, dtype=torch.int64)
        
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = torch.tensor([idx])
        
        if self.transforms is not None:
            img = self.transforms(img)
        
        return img, target

    def __len__(self):
        return len(self.image_files)

def collate_fn(batch):
    return tuple(zip(*batch))

# ---------------------------
# Set Up Dataset and DataLoader
# ---------------------------
train_images_dir = "/kaggle/input/muid-iitr-train-val-test-split/split_data/train/images"
train_labels_dir = "/kaggle/input/muid-iitr-train-val-test-split/split_data/train/labels"
val_images_dir = "/kaggle/input/muid-iitr-train-val-test-split/split_data/validation/images"
val_labels_dir = "/kaggle/input/muid-iitr-train-val-test-split/split_data/validation/labels"

# Define transforms: here we simply convert images to tensor.
data_transforms = transforms.Compose([
    transforms.ToTensor()
])

train_dataset = YoloDataset(train_images_dir, train_labels_dir, transforms=data_transforms)
val_dataset = YoloDataset(val_images_dir, val_labels_dir, transforms=data_transforms)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=collate_fn, num_workers=2)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=4, shuffle=False, collate_fn=collate_fn, num_workers=2)

# ---------------------------
# Set Up Faster R-CNN Model
# ---------------------------
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# Number of classes (include background as class 0)
num_classes = 2  # For example, 1 object class ("phone") + background

# Load a pretrained Faster R-CNN model
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
# Replace the classifier head with a new one for our number of classes.
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes)
model.to(device)

for name, param in model.backbone.body.named_parameters():
    param.requires_grad = False

# ---------------------------
# Define Optimizer and Learning Rate Scheduler
# ---------------------------
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# ---------------------------
# Training Loop with Validation, Best Model Saving, and Validation Accuracy
# ---------------------------
num_epochs = 15  # Change as needed
best_val_loss = float('inf')

for epoch in range(num_epochs):
    # ---- Training Phase ----
    model.train()
    running_loss = 0.0
    for images, targets in train_loader:
        images = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        running_loss += losses.item()
        
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
    
    lr_scheduler.step()
    train_loss = running_loss / len(train_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {train_loss:.4f}")
    
    # ---- Validation Phase (Compute Loss) ----
    # We use model.train() with no grad to force the model to return losses.
    model.train()
    val_running_loss = 0.0
    with torch.no_grad():
        for images, targets in val_loader:
            images = [img.to(device) for img in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())
            val_running_loss += losses.item()
    
    val_loss = val_running_loss / len(val_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Validation Loss: {val_loss:.4f}")
    
    # ---- Compute Validation "Accuracy" ----
    # We switch to evaluation mode (which returns predictions) and compute a simple metric:
    # For each validation image, we count the fraction of ground truth boxes that have a matching predicted box (IoU >= 0.5).
    model.eval()
    all_acc = []
    with torch.no_grad():
        for images, targets in val_loader:
            images = [img.to(device) for img in images]
            predictions = model(images)  # This returns predictions in eval mode
            for i in range(len(predictions)):
                gt_boxes = targets[i]['boxes'].cpu().numpy()
                pred_boxes = predictions[i]['boxes'].cpu().numpy()
                # Skip images with no ground truth boxes
                if len(gt_boxes) == 0:
                    continue
                count = 0
                for gt in gt_boxes:
                    matched = False
                    for pb in pred_boxes:
                        if compute_iou_np(gt, pb) >= 0.5:
                            matched = True
                            break
                    if matched:
                        count += 1
                acc = count / len(gt_boxes)
                all_acc.append(acc)
    val_acc = np.mean(all_acc) if all_acc else 0.0
    print(f"Epoch [{epoch+1}/{num_epochs}], Validation Accuracy (IoU>=0.5): {val_acc:.4f}")
    
    # ---- Save Best Model Based on Validation Loss ----
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), "best.pt")
        print(f"Saved best model at epoch {epoch+1} with validation loss: {best_val_loss:.4f}")

print("Training complete.")

# ---------------------------
# Helper IoU Function for Validation Accuracy
# ---------------------------
def compute_iou_np(box1, box2):
    xi1 = max(box1[0], box2[0])
    yi1 = max(box1[1], box2[1])
    xi2 = min(box1[2], box2[2])
    yi2 = min(box1[3], box2[3])
    inter_width = max(0, xi2 - xi1)
    inter_height = max(0, yi2 - yi1)
    inter_area = inter_width * inter_height
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union_area = box1_area + box2_area - inter_area
    return inter_area / union_area if union_area > 0 else 0
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:00<00:00, 205MB/s]
# Epoch [1/15], Training Loss: 0.1653
# Epoch [1/15], Validation Loss: 0.1312
# Epoch [1/15], Validation Accuracy (IoU>=0.5): 0.9506
# Saved best model at epoch 1 with validation loss: 0.1312
# Epoch [2/15], Training Loss: 0.1311
# Epoch [2/15], Validation Loss: 0.1186
# Epoch [2/15], Validation Accuracy (IoU>=0.5): 0.9321
# Saved best model at epoch 2 with validation loss: 0.1186
# Epoch [3/15], Training Loss: 0.1217
# Epoch [3/15], Validation Loss: 0.1150
# Epoch [3/15], Validation Accuracy (IoU>=0.5): 0.9383
# Saved best model at epoch 3 with validation loss: 0.1150
# Epoch [4/15], Training Loss: 0.1127
# Epoch [4/15], Validation Loss: 0.1111
# Epoch [4/15], Validation Accuracy (IoU>=0.5): 0.9136
# Saved best model at epoch 4 with validation loss: 0.1111
# Epoch [5/15], Training Loss: 0.1105
# Epoch [5/15], Validation Loss: 0.1122
# Epoch [5/15], Validation Accuracy (IoU>=0.5): 0.9136
# Epoch [6/15], Training Loss: 0.1095
# Epoch [6/15], Validation Loss: 0.1106
# Epoch [6/15], Validation Accuracy (IoU>=0.5): 0.9136
# Saved best model at epoch 6 with validation loss: 0.1106
# Epoch [7/15], Training Loss: 0.1087
# Epoch [7/15], Validation Loss: 0.1107
# Epoch [7/15], Validation Accuracy (IoU>=0.5): 0.9136
# Epoch [8/15], Training Loss: 0.1086
# Epoch [8/15], Validation Loss: 0.1092
# Epoch [8/15], Validation Accuracy (IoU>=0.5): 0.9136
# Saved best model at epoch 8 with validation loss: 0.1092
# Epoch [9/15], Training Loss: 0.1083
# Epoch [9/15], Validation Loss: 0.1103
# Epoch [9/15], Validation Accuracy (IoU>=0.5): 0.9136
# Epoch [10/15], Training Loss: 0.1078
# Epoch [10/15], Validation Loss: 0.1113
# Epoch [10/15], Validation Accuracy (IoU>=0.5): 0.9136
# Epoch [11/15], Training Loss: 0.1080
# Epoch [11/15], Validation Loss: 0.1111
# Epoch [11/15], Validation Accuracy (IoU>=0.5): 0.9136
# Epoch [12/15], Training Loss: 0.1084
# Epoch [12/15], Validation Loss: 0.1099
# Epoch [12/15], Validation Accuracy (IoU>=0.5): 0.9136
# Epoch [13/15], Training Loss: 0.1079
# Epoch [13/15], Validation Loss: 0.1107
# Epoch [13/15], Validation Accuracy (IoU>=0.5): 0.9136
# Epoch [14/15], Training Loss: 0.1089
# Epoch [14/15], Validation Loss: 0.1102
# Epoch [14/15], Validation Accuracy (IoU>=0.5): 0.9136
# Epoch [15/15], Training Loss: 0.1083
# Epoch [15/15], Validation Loss: 0.1105
# Epoch [15/15], Validation Accuracy (IoU>=0.5): 0.9136
# Training complete.

# %%
# !pip install torch torchvision opencv-python-headless pandas numpy scipy

#!/usr/bin/env python3
import os
import glob
import shutil
import cv2
import pandas as pd
import numpy as np
import torch
import torchvision
from torchvision.transforms import functional as F
from scipy.optimize import linear_sum_assignment  # For optimal matching

# ---------------------------
# Helper Functions
# ---------------------------

def rename_test_images_and_labels_in_new_folder(src_images_dir, src_labels_dir, dst_images_dir, dst_labels_dir):
    """
    Copies all jpg images from src_images_dir to dst_images_dir and renames them sequentially (1.jpg, 2.jpg, etc).
    Also copies the corresponding label files from src_labels_dir to dst_labels_dir, renaming them accordingly.
    """
    os.makedirs(dst_images_dir, exist_ok=True)
    os.makedirs(dst_labels_dir, exist_ok=True)
    
    image_files = sorted(glob.glob(os.path.join(src_images_dir, '*.jpg')))
    
    for i, image_path in enumerate(image_files, start=1):
        new_image_filename = f"{i}.jpg"
        new_label_filename = f"{i}.txt"
        
        new_image_path = os.path.join(dst_images_dir, new_image_filename)
        new_label_path = os.path.join(dst_labels_dir, new_label_filename)
        
        shutil.copy(image_path, new_image_path)
        
        old_base = os.path.splitext(os.path.basename(image_path))[0]
        old_label_path = os.path.join(src_labels_dir, f"{old_base}.txt")
        
        if os.path.exists(old_label_path):
            shutil.copy(old_label_path, new_label_path)
    
    print(f"Copied and renamed {len(image_files)} images from '{src_images_dir}' to '{dst_images_dir}', "
          f"and corresponding labels from '{src_labels_dir}' to '{dst_labels_dir}'.")

def read_ground_truth_labels(label_file):
    """
    Reads a YOLO ground-truth label file (no confidence) and returns a list of boxes in
    normalized [x_min, y_min, x_max, y_max] format.
    Each line: class_id center_x center_y width height
    """
    if not os.path.exists(label_file):
        return []
    
    boxes = []
    with open(label_file, "r") as f:
        for line in f:
            parts = list(map(float, line.split()))
            if len(parts) != 5:
                continue
            _, cx, cy, w, h = parts  # YOLO format (normalized)
            # Convert center/width/height to x_min, y_min, x_max, y_max
            x_min = cx - (w / 2)
            y_min = cy - (h / 2)
            x_max = cx + (w / 2)
            y_max = cy + (h / 2)
            boxes.append([x_min, y_min, x_max, y_max])
    return boxes

def read_prediction_labels(label_file):
    """
    Reads a prediction label file (with confidence) and returns a list of boxes in
    normalized [x_min, y_min, x_max, y_max, confidence] format.
    Each line: class_id center_x center_y width height confidence
    """
    if not os.path.exists(label_file):
        return []
    
    boxes = []
    with open(label_file, "r") as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 6:
                continue
            cls_id = float(parts[0])
            cx = float(parts[1])
            cy = float(parts[2])
            w = float(parts[3])
            h = float(parts[4])
            conf = float(parts[5])
            # Convert to x_min, y_min, x_max, y_max
            x_min = cx - (w / 2)
            y_min = cy - (h / 2)
            x_max = cx + (w / 2)
            y_max = cy + (h / 2)
            boxes.append([x_min, y_min, x_max, y_max, conf])
    return boxes

def compute_iou(box1, box2):
    """
    Computes Intersection over Union (IoU) between two boxes in [x1, y1, x2, y2] format.
    """
    xi1 = max(box1[0], box2[0])
    yi1 = max(box1[1], box2[1])
    xi2 = min(box1[2], box2[2])
    yi2 = min(box1[3], box2[3])
    inter_width = max(0, xi2 - xi1)
    inter_height = max(0, yi2 - yi1)
    inter_area = inter_width * inter_height

    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union_area = box1_area + box2_area - inter_area

    return inter_area / union_area if union_area > 0 else 0

def process_failure_cases(test_images_dir, ground_truth_dir, predictions_labels_dir, annotated_base_dir, iou_threshold):
    """
    For each test image, compares predicted and ground truth boxes.
    A failure is flagged if:
      1. The number of predicted boxes != ground truth boxes (label mismatch).
      2. Any corresponding pair's IoU (from the best matching) is below the threshold (IoU failure).

    In failure cases:
      - Annotated images are saved in subfolders of `annotated_base_dir`:
         * iou_threshold/      (if the best-matched IoU is below threshold)
         * label_mismatch/     (if the number of boxes mismatches)
      - A CSV is generated (failure_cases.csv) listing each failed image,
        its IoU values, counts, threshold, and in which folder(s) it was stored.
    """
    iou_failure_subfolder = os.path.join(annotated_base_dir, "iou_threshold")
    mismatch_failure_subfolder = os.path.join(annotated_base_dir, "label_mismatch")
    os.makedirs(iou_failure_subfolder, exist_ok=True)
    os.makedirs(mismatch_failure_subfolder, exist_ok=True)
    
    failure_data = []
    image_files = sorted(glob.glob(os.path.join(test_images_dir, '*.jpg')))
    print(f"Processing {len(image_files)} images in {test_images_dir}.")
    
    for image_file in image_files:
        base = os.path.splitext(os.path.basename(image_file))[0]
        gt_file = os.path.join(ground_truth_dir, base + '.txt')
        pred_file = os.path.join(predictions_labels_dir, base + '.txt')
        
        gt_boxes = read_ground_truth_labels(gt_file)
        pred_boxes = read_prediction_labels(pred_file)
        
        label_mismatch = (len(gt_boxes) != len(pred_boxes))
        low_iou = False
        iou_values = []
        
        if gt_boxes and pred_boxes:
            cost_matrix = np.zeros((len(gt_boxes), len(pred_boxes)))
            for i, gt in enumerate(gt_boxes):
                for j, pred in enumerate(pred_boxes):
                    cost_matrix[i, j] = -compute_iou(gt, pred[:4])
            row_ind, col_ind = linear_sum_assignment(cost_matrix)
            for i, j in zip(row_ind, col_ind):
                iou_val = compute_iou(gt_boxes[i], pred_boxes[j][:4])
                iou_values.append(iou_val)
                if iou_val < iou_threshold:
                    low_iou = True
        
        if label_mismatch or low_iou:
            img = cv2.imread(image_file)
            if img is None:
                print(f"Could not load image: {image_file}")
                continue

            height, width = img.shape[:2]
            for box_gt in gt_boxes:
                x_min, y_min, x_max, y_max = box_gt
                pt1 = (int(x_min * width), int(y_min * height))
                pt2 = (int(x_max * width), int(y_max * height))
                cv2.rectangle(img, pt1, pt2, (0, 255, 0), 2)
                cv2.putText(img, "GT", (pt1[0], max(pt1[1]-5, 0)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
            for box_pred in pred_boxes:
                x_min, y_min, x_max, y_max, conf = box_pred
                pt1 = (int(x_min * width), int(y_min * height))
                pt2 = (int(x_max * width), int(y_max * height))
                cv2.rectangle(img, pt1, pt2, (0, 0, 255), 2)
                cv2.putText(img, f"{conf:.2f}", (pt1[0], max(pt1[1]-5, 0)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
            
            failure_reasons = []
            if label_mismatch:
                failure_reasons.append("label_mismatch")
                mismatch_path = os.path.join(mismatch_failure_subfolder, os.path.basename(image_file))
                cv2.imwrite(mismatch_path, img)
            if low_iou:
                failure_reasons.append("iou_threshold")
                iou_path = os.path.join(iou_failure_subfolder, os.path.basename(image_file))
                cv2.imwrite(iou_path, img)
            
            failure_data.append({
                'image': os.path.basename(image_file),
                'iou_values': iou_values,
                'ground_truth_count': len(gt_boxes),
                'predicted_count': len(pred_boxes),
                'iou_threshold': iou_threshold,
                'failure_folders': ",".join(failure_reasons)
            })
    
    df = pd.DataFrame(failure_data)
    csv_filename = 'failure_cases.csv'
    df.to_csv(csv_filename, index=False)
    print(f"Failure cases processed. CSV saved as {csv_filename}.")

def predict_test_images(model_path, source_dir, predictions_output_dir, conf_threshold=0.5, num_classes=2):
    """
    Runs Faster R-CNN prediction on all images in source_dir using the checkpoint at model_path.
    Saves prediction .txt files in YOLO format (normalized [class center_x center_y width height confidence])
    and annotated images with bounding boxes.
    
    The Faster R-CNN outputs boxes in absolute pixel coordinates; these are converted to normalized coordinates.
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # Instantiate the model with the correct number of classes.
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=False, num_classes=num_classes)
    checkpoint = torch.load(model_path, map_location=device)
    model.load_state_dict(checkpoint)
    model.to(device)
    model.eval()
    
    # Prepare output directories.
    images_output = os.path.join(predictions_output_dir, "images")
    labels_output = os.path.join(predictions_output_dir, "labels")
    os.makedirs(images_output, exist_ok=True)
    os.makedirs(labels_output, exist_ok=True)
    
    image_paths = sorted(glob.glob(os.path.join(source_dir, '*.jpg')))
    
    with torch.no_grad():
        for image_path in image_paths:
            # Read image and convert to RGB.
            orig_img = cv2.imread(image_path)
            if orig_img is None:
                print(f"Could not load image: {image_path}")
                continue
            img_rgb = cv2.cvtColor(orig_img, cv2.COLOR_BGR2RGB)
            pil_img = torchvision.transforms.functional.to_pil_image(img_rgb)
            img_tensor = F.to_tensor(pil_img).to(device)
            
            # Inference.
            outputs = model([img_tensor])
            output = outputs[0]
            
            # Get image dimensions.
            height, width = orig_img.shape[:2]
            predictions = []
            
            # Process each detected box.
            for box, score, label in zip(output['boxes'], output['scores'], output['labels']):
                if score < conf_threshold:
                    continue
                # Convert box from [x1, y1, x2, y2] (absolute) to YOLO format normalized:
                x1, y1, x2, y2 = box.cpu().numpy()
                box_width = x2 - x1
                box_height = y2 - y1
                center_x = x1 + box_width / 2
                center_y = y1 + box_height / 2
                # Normalize
                center_x_norm = center_x / width
                center_y_norm = center_y / height
                box_width_norm = box_width / width
                box_height_norm = box_height / height
                predictions.append([float(label), center_x_norm, center_y_norm, box_width_norm, box_height_norm, float(score)])
                # Draw the predicted box.
                pt1 = (int(x1), int(y1))
                pt2 = (int(x2), int(y2))
                cv2.rectangle(orig_img, pt1, pt2, (0, 0, 255), 2)
                cv2.putText(orig_img, f"{score:.2f}", (pt1[0], max(pt1[1]-5, 0)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
            
            # Save annotated image.
            base_name = os.path.basename(image_path)
            cv2.imwrite(os.path.join(images_output, base_name), orig_img)
            
            # Save predictions in txt file (YOLO format: class center_x center_y width height confidence).
            txt_filename = os.path.splitext(base_name)[0] + ".txt"
            with open(os.path.join(labels_output, txt_filename), "w") as f:
                for pred in predictions:
                    f.write(" ".join(map(str, pred)) + "\n")
    
    print(f"Predicted annotated images saved in {images_output} and prediction labels in {labels_output}")
    return {"images": images_output, "labels": labels_output}

# ---------------------------
# Main Execution
# ---------------------------

if __name__ == "__main__":
    # Update these paths as needed.
    test_images_dir = '/kaggle/working/split_data/test/images'          # Original test images
    ground_truth_dir = '/kaggle/working/split_data/test/labels'         # Original ground truth labels
    predictions_base_dir = '/kaggle/working/predicted'                  # Base folder for prediction outputs
    annotated_failures_dir = '/kaggle/working/annotated_failure'        # Base folder for annotated failure images
    test_new_images_dir = '/kaggle/working/test_new/images'             # Folder for renamed test images
    test_new_labels_dir = '/kaggle/working/test_new/labels'             # Folder for renamed label files
    
    # Set IoU threshold.
    iou_threshold = 0.5

    # Step 1: Rename/copy test images and labels.
    rename_test_images_and_labels_in_new_folder(
        test_images_dir,
        ground_truth_dir,
        test_new_images_dir,
        test_new_labels_dir
    )
    
    # Step 2: Run predictions on the new test images using the Faster R-CNN model.
    model_path = '/kaggle/working/best.pt'  # Path to your Faster R-CNN checkpoint.
    pred_dict = predict_test_images(model_path, test_new_images_dir, predictions_base_dir, conf_threshold=0.5, num_classes=2)
    predicted_images_dir = pred_dict["images"]
    predicted_labels_dir = pred_dict["labels"]
    
    # Step 3: Process predictions vs ground truth, annotate failure cases, and output CSV.
    process_failure_cases(
        test_new_images_dir,
        test_new_labels_dir,
        predicted_labels_dir,
        annotated_failures_dir,
        iou_threshold
    )
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.7.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.22.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.2.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/dist-packages (from torch) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/dist-packages (from torch) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.0->torch) (75.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Copied and renamed 0 images from '/kaggle/working/split_data/test/images' to '/kaggle/working/test_new/images', and corresponding labels from '/kaggle/working/split_data/test/labels' to '/kaggle/working/test_new/labels'.
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 223MB/s]
# Predicted annotated images saved in /kaggle/working/predicted/images and prediction labels in /kaggle/working/predicted/labels
# Processing 0 images in /kaggle/working/test_new/images.
# Failure cases processed. CSV saved as failure_cases.csv.

# %%
# !cd /kaggle/working && zip -r working.zip . -x "working.zip"

from IPython.display import FileLink
FileLink('/kaggle/working/working.zip')
# Out:
#   adding: predicted/ (stored 0%)
#   adding: predicted/images/ (stored 0%)
#   adding: predicted/labels/ (stored 0%)
#   adding: annotated_failure/ (stored 0%)
#   adding: annotated_failure/label_mismatch/ (stored 0%)
#   adding: annotated_failure/iou_threshold/ (stored 0%)
#   adding: test_new/ (stored 0%)
#   adding: test_new/images/ (stored 0%)
#   adding: test_new/labels/ (stored 0%)
#   adding: best.pt (deflated 7%)
#   adding: failure_cases.csv (stored 0%)
#   adding: __notebook__.ipynb (deflated 95%)
# /kaggle/working/working.zip
